# %% [markdown]
# # Overview
# This notebook serves as a brief example of how to possibly make changes to the model through script for two types of changes:
# 1. single node changes
# 2. multi-node changes

# %% [markdown]
# # Build the model
# We need to first have the model ready before using the function. All steps of building the model are the same as indicated in the Quickstart notebook. We do not run the model yet as we need to make the changes beforehand.

# %%
import pyCIMS
import pprint as pp

# description file
model_description_file = '../../model_descriptions/pyCIMS_model_description_Alberta_Test.xlsb'

# model validator
model_validator = pyCIMS.ModelValidator(model_description_file)
model_validator.validate(verbose=True, raise_warnings=False)

# Model Reader
model_reader = pyCIMS.ModelReader(infile=model_description_file,
                                  sheet_map={'model': 'Model', 
                                             'default_tech': 'Technology_Node templates'},
                                  node_col='Node')

# Model
model = pyCIMS.Model(model_reader)
# Out:
# /Users/adrienawong/.pyenv/versions/3.7.0/lib/python3.7/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# 0 node name/branch mismatches.
# 0 references to unspecified nodes.
# 0 non-root nodes are never referenced.
# 0 nodes were specified but don't provide a service.
# 0 nodes had invalid competition types.
# 0 nodes requested services of themselves.
# 46 nodes or technologies don't request other services. See ModelValidator.warnings['nodes_no_requested_service'] for more info.
# 1863 nodes have been defined in a different order between the model and tree sheets. See ModelValidator.warnings['discrepencies_in_model_and_tree'] for more info.
# 0 nodes have 0 in the output line.
# 0 fuel nodes don't have an Life Cycle Cost.
# 0 tech compete nodes don't have capital cost.
# 60 nodes have market shares that don't sum to 100%. See ModelValidator.warnings['nodes_with_bad_total_ms'] for more info.
# 0 technologies are missing a base year market share.
# 1 nodes/technologies request from the same service more than once. See ModelValidator.warnings['duplicate_req'] for more info.
# 36 nodes/technologies contain 0's or are missing values in service request rows. See ModelValidator.warnings['bad_service_req'] for more info.
# 0 tech compete nodes don't contain Technology or Service headings

# %% [markdown]
# For formatting purposes:

# %%
dash = '-' * 90

# %% [markdown]
# ### Single Node Changes

# %% [markdown]
# 1. At node pyCIMS.Canada.Alberta.Residential.Buildings.Floorspace.Lighting update the Market share in year "2000" for the Incandescent & CFL technologies to 0.8 and 0.2, respectively.

# %%
node_to_change = 'pyCIMS.Canada.Alberta.Residential.Buildings.Floorspace.Lighting'
year = '2000'
tech = 'Incandescent'

print(node_to_change)
print(year)
print(tech)

print(dash)
print('Previous value: ' + str(model.graph.nodes[node_to_change][year]['technologies'][tech]['Market share']['year_value']))
model.graph.nodes[node_to_change][year]['technologies'][tech]['Market share']['year_value'] = 0.8
print('New value: ' + str(model.graph.nodes[node_to_change][year]['technologies'][tech]['Market share']['year_value']))
# Out:
# pyCIMS.Canada.Alberta.Residential.Buildings.Floorspace.Lighting
# 2000
# Incandescent
# ------------------------------------------------------------------------------------------
# Previous value: 0.92
# New value: 0.8

# %%
tech = 'CFL'

print(node_to_change)
print(year)
print(tech)
print(dash)
print('Previous value: ' + str(model.graph.nodes[node_to_change][year]['technologies'][tech]['Market share']['year_value']))
model.graph.nodes[node_to_change][year]['technologies'][tech]['Market share']['year_value'] = 0.2
print('New value: ' + str(model.graph.nodes[node_to_change][year]['technologies'][tech]['Market share']['year_value']))
# Out:
# pyCIMS.Canada.Alberta.Residential.Buildings.Floorspace.Lighting
# 2000
# CFL
# ------------------------------------------------------------------------------------------
# Previous value: 0.08
# New value: 0.2

# %% [markdown]
# 2. At node pyCIMS.Canada.Alberta.Transportation Personal.Passenger Vehicles.Existing update the Service requested value in all years for the Recent Car and Old Truck technologies to 0.7 and 0.3, respectively.

# %%
node_to_change = 'pyCIMS.Canada.Alberta.Transportation Personal.Passenger Vehicles.Existing'
service_requested = 'Recent Car'

print(node_to_change)
print(service_requested)
print(dash)
for year in model.years:
    print(year)
    print('Previous value: ' + str(model.graph.nodes[node_to_change][year]['Service requested'][service_requested]['year_value']))
    model.graph.nodes[node_to_change][year]['Service requested']['Recent Car']['year_value'] = 0.7
    print('New value: ' + str(model.graph.nodes[node_to_change][year]['Service requested'][service_requested]['year_value']))
    print(dash)
# Out:
# pyCIMS.Canada.Alberta.Transportation Personal.Passenger Vehicles.Existing
# Recent Car
# ------------------------------------------------------------------------------------------
# 2000
# Previous value: 0.642948225
# New value: 0.7
# ------------------------------------------------------------------------------------------
# 2005
# Previous value: 0.642948225
# New value: 0.7
# ------------------------------------------------------------------------------------------
# 2010
# Previous value: 0.642948225
# New value: 0.7
# ------------------------------------------------------------------------------------------
# 2015
# Previous value: 0.642948225
# New value: 0.7
# ------------------------------------------------------------------------------------------
# 2020
# Previous value: 0.642948225
# New value: 0.7
# ------------------------------------------------------------------------------------------
# 2025
# Previous value: 0.642948225
# New value: 0.7
# ------------------------------------------------------------------------------------------
# 2030
# Previous value: 0.642948225
# New value: 0.7
# ------------------------------------------------------------------------------------------
# 2035
# Previous value: 0.642948225
# New value: 0.7
# ------------------------------------------------------------------------------------------
# 2040
# Previous value: 0.642948225
# New value: 0.7
# ------------------------------------------------------------------------------------------
# 2045
# Previous value: 0.642948225
# New value: 0.7
# ------------------------------------------------------------------------------------------
# 2050
# Previous value: 0.642948225
# New value: 0.7
# ------------------------------------------------------------------------------------------

# %%
service_requested = 'Old Truck'

print(node_to_change)
print(service_requested)
print(dash)
for year in model.years:
    print(year)
    print('Previous value: ' + str(model.graph.nodes[node_to_change][year]['Service requested'][service_requested]['year_value']))
    model.graph.nodes[node_to_change][year]['Service requested'][service_requested]['year_value'] = 0.3
    print('New value: ' + str(model.graph.nodes[node_to_change][year]['Service requested'][service_requested]['year_value']))
    print(dash)
# Out:
# pyCIMS.Canada.Alberta.Transportation Personal.Passenger Vehicles.Existing
# Old Truck
# ------------------------------------------------------------------------------------------
# 2000
# Previous value: 0.357051775
# New value: 0.3
# ------------------------------------------------------------------------------------------
# 2005
# Previous value: 0.357051775
# New value: 0.3
# ------------------------------------------------------------------------------------------
# 2010
# Previous value: 0.357051775
# New value: 0.3
# ------------------------------------------------------------------------------------------
# 2015
# Previous value: 0.357051775
# New value: 0.3
# ------------------------------------------------------------------------------------------
# 2020
# Previous value: 0.357051775
# New value: 0.3
# ------------------------------------------------------------------------------------------
# 2025
# Previous value: 0.357051775
# New value: 0.3
# ------------------------------------------------------------------------------------------
# 2030
# Previous value: 0.357051775
# New value: 0.3
# ------------------------------------------------------------------------------------------
# 2035
# Previous value: 0.357051775
# New value: 0.3
# ------------------------------------------------------------------------------------------
# 2040
# Previous value: 0.357051775
# New value: 0.3
# ------------------------------------------------------------------------------------------
# 2045
# Previous value: 0.357051775
# New value: 0.3
# ------------------------------------------------------------------------------------------
# 2050
# Previous value: 0.357051775
# New value: 0.3
# ------------------------------------------------------------------------------------------

# %% [markdown]
# 3. At node pyCIMS.Canada.Alberta.Propane increase the Life Cycle Cost value for all years from 2020 onwards by 2.2.

# %%
node_to_change = 'pyCIMS.Canada.Alberta.Propane'
relevant_years = [x for x in model.years if int(x) >= 2020]

print(node_to_change)
print('Life Cycle Cost')
print(dash)
for year in relevant_years:
    print(year)
    print('Previous value: ' + str(model.graph.nodes['pyCIMS.Canada.Alberta.Propane'][year]['Life Cycle Cost'][None]['year_value']))
    model.graph.nodes['pyCIMS.Canada.Alberta.Propane'][year]['Life Cycle Cost'][None]['year_value'] += 2.2
    print('New value: ' + str(model.graph.nodes['pyCIMS.Canada.Alberta.Propane'][year]['Life Cycle Cost'][None]['year_value']))
    print(dash)
# Out:
# pyCIMS.Canada.Alberta.Propane
# Life Cycle Cost
# ------------------------------------------------------------------------------------------
# 2020
# Previous value: 60.75
# New value: 62.95
# ------------------------------------------------------------------------------------------
# 2025
# Previous value: 64.36
# New value: 66.56
# ------------------------------------------------------------------------------------------
# 2030
# Previous value: 66.98
# New value: 69.18
# ------------------------------------------------------------------------------------------
# 2035
# Previous value: 68.41
# New value: 70.61
# ------------------------------------------------------------------------------------------
# 2040
# Previous value: 70.08
# New value: 72.28
# ------------------------------------------------------------------------------------------
# 2045
# Previous value: 70.08
# New value: 72.28
# ------------------------------------------------------------------------------------------
# 2050
# Previous value: 70.08
# New value: 72.28
# ------------------------------------------------------------------------------------------

# %% [markdown]
# 4. At node pyCIMS.Canada.Alberta.Transportation Personal.Transit.Public Bus.Std Emissions set the heterogeneity value to 25 for all years

# %%
node_to_change = 'pyCIMS.Canada.Alberta.Transportation Personal.Transit.Public Bus.Standard Emissions'

print(node_to_change)
print('Heterogeneity')
print(dash)
for year in model.years:
    print(year)
    print('Previous value: ' + str(model.graph.nodes[node_to_change][year]['Heterogeneity'][None]['year_value']))
    model.graph.nodes[node_to_change][year]['Heterogeneity'][None]['year_value'] = 25
    print('New value: ' + str(model.graph.nodes[node_to_change][year]['Heterogeneity'][None]['year_value']))
    print(dash)
# Out:
# pyCIMS.Canada.Alberta.Transportation Personal.Transit.Public Bus.Standard Emissions
# Heterogeneity
# ------------------------------------------------------------------------------------------
# 2000
# Previous value: 20.0
# New value: 25
# ------------------------------------------------------------------------------------------
# 2005
# Previous value: 20.0
# New value: 25
# ------------------------------------------------------------------------------------------
# 2010
# Previous value: 20.0
# New value: 25
# ------------------------------------------------------------------------------------------
# 2015
# Previous value: 20.0
# New value: 25
# ------------------------------------------------------------------------------------------
# 2020
# Previous value: 20.0
# New value: 25
# ------------------------------------------------------------------------------------------
# 2025
# Previous value: 20.0
# New value: 25
# ------------------------------------------------------------------------------------------
# 2030
# Previous value: 20.0
# New value: 25
# ------------------------------------------------------------------------------------------
# 2035
# Previous value: 20.0
# New value: 25
# ------------------------------------------------------------------------------------------
# 2040
# Previous value: 20.0
# New value: 25
# ------------------------------------------------------------------------------------------
# 2045
# Previous value: 20.0
# New value: 25
# ------------------------------------------------------------------------------------------
# 2050
# Previous value: 20.0
# New value: 25
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ### Multiple Node Changes

# %% [markdown]
# 1. Increase Price Multiplier values in all years for all sector nodes (competition type == Sector or Sector No Tech) by 0.1.

# %%
for node in model.graph.nodes:
    if model.graph.nodes[node]['competition type'] in ['sector', 'sector no tech']:
        
        for year in model.years:
            try:
                for key in model.graph.nodes[node][year]['Price Multiplier'].keys():
                    prev_val = model.graph.nodes[node][year]['Price Multiplier'][key]['year_value']
                    print(node)
                    print('Price Multiplier')
                    print(year)
                    print(key)
                    print('Previous value: ' + str(prev_val))
                    model.graph.nodes[node][year]['Price Multiplier'][key]['year_value'] += 0.1
                    print('New value: ' + str(model.graph.nodes[node][year]['Price Multiplier'][key]['year_value']))
                    print(dash)
            except: #KeyError
                continue
# Out:
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2000
# Diesel
# Previous value: 2.8832719819482935
# New value: 2.9832719819482936
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2000
# Light Fuel Oil
# Previous value: 2.8832719819482935
# New value: 2.9832719819482936
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2000
# Natural Gas
# Previous value: 1.185318514096392
# New value: 1.285318514096392
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2000
# Electricity
# Previous value: 2.877762716911787
# New value: 2.977762716911787
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2000
# Wood
# Previous value: 7.924040444009997
# New value: 8.024040444009998
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2005
# Diesel
# Previous value: 2.9163557015722947
# New value: 3.016355701572295
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2005
# Light Fuel Oil
# Previous value: 2.9163557015722947
# New value: 3.016355701572295
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2005
# Natural Gas
# Previous value: 1.1989194923299649
# New value: 1.298919492329965
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2005
# Electricity
# Previous value: 1.3049238777800118
# New value: 1.404923877780012
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2005
# Wood
# Previous value: 10.01384475000787
# New value: 10.11384475000787
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2010
# Diesel
# Previous value: 1.914849570121868
# New value: 2.014849570121868
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2010
# Light Fuel Oil
# Previous value: 1.914849570121868
# New value: 2.014849570121868
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2010
# Natural Gas
# Previous value: 1.712300749964769
# New value: 1.8123007499647692
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2010
# Electricity
# Previous value: 1.0378489260143198
# New value: 1.1378489260143199
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2010
# Wood
# Previous value: 52.264236153877825
# New value: 52.364236153877826
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2015
# Diesel
# Previous value: 3.567136384607496
# New value: 3.6671363846074962
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2015
# Light Fuel Oil
# Previous value: 3.567136384607496
# New value: 3.6671363846074962
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2015
# Natural Gas
# Previous value: 1.3992793347589847
# New value: 1.4992793347589848
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2015
# Electricity
# Previous value: 0.8972818698347107
# New value: 0.9972818698347107
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2015
# Wood
# Previous value: 52.264236153877825
# New value: 52.364236153877826
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2020
# Diesel
# Previous value: 3.9008645855307864
# New value: 4.0008645855307865
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2020
# Light Fuel Oil
# Previous value: 3.9008645855307864
# New value: 4.0008645855307865
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2020
# Natural Gas
# Previous value: 4.984172152179559
# New value: 5.084172152179558
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2020
# Electricity
# Previous value: 0.8220173329894247
# New value: 0.9220173329894247
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2020
# Wood
# Previous value: 52.264236153877825
# New value: 52.364236153877826
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2025
# Diesel
# Previous value: 3.0366596203927365
# New value: 3.1366596203927366
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2025
# Light Fuel Oil
# Previous value: 3.0366596203927365
# New value: 3.1366596203927366
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2025
# Natural Gas
# Previous value: 3.444996570523813
# New value: 3.544996570523813
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2025
# Electricity
# Previous value: 0.8325368794326242
# New value: 0.9325368794326242
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2025
# Wood
# Previous value: 52.264236153877825
# New value: 52.364236153877826
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2030
# Diesel
# Previous value: 2.871839401680371
# New value: 2.9718394016803713
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2030
# Light Fuel Oil
# Previous value: 2.871839401680371
# New value: 2.9718394016803713
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2030
# Natural Gas
# Previous value: 2.782905252835355
# New value: 2.882905252835355
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2030
# Electricity
# Previous value: 0.847245265151515
# New value: 0.947245265151515
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2030
# Wood
# Previous value: 52.264236153877825
# New value: 52.364236153877826
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2035
# Diesel
# Previous value: 2.8264896979477454
# New value: 2.9264896979477455
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2035
# Light Fuel Oil
# Previous value: 2.8264896979477454
# New value: 2.9264896979477455
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2035
# Natural Gas
# Previous value: 2.5154296345316487
# New value: 2.615429634531649
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2035
# Electricity
# Previous value: 0.8424008888888889
# New value: 0.9424008888888888
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2035
# Wood
# Previous value: 52.264236153877825
# New value: 52.364236153877826
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2040
# Diesel
# Previous value: 2.819085664685276
# New value: 2.919085664685276
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2040
# Light Fuel Oil
# Previous value: 2.819085664685276
# New value: 2.919085664685276
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2040
# Natural Gas
# Previous value: 2.361660027764593
# New value: 2.461660027764593
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2040
# Electricity
# Previous value: 0.8424008888888889
# New value: 0.9424008888888888
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2040
# Wood
# Previous value: 52.264236153877825
# New value: 52.364236153877826
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2045
# Diesel
# Previous value: 2.819085664685276
# New value: 2.919085664685276
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2045
# Light Fuel Oil
# Previous value: 2.819085664685276
# New value: 2.919085664685276
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2045
# Natural Gas
# Previous value: 2.361660027764593
# New value: 2.461660027764593
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2045
# Electricity
# Previous value: 0.8424008888888889
# New value: 0.9424008888888888
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2045
# Wood
# Previous value: 52.264236153877825
# New value: 52.364236153877826
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2050
# Diesel
# Previous value: 2.819085664685276
# New value: 2.919085664685276
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2050
# Light Fuel Oil
# Previous value: 2.819085664685276
# New value: 2.919085664685276
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2050
# Natural Gas
# Previous value: 2.361660027764593
# New value: 2.461660027764593
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2050
# Electricity
# Previous value: 0.8424008888888889
# New value: 0.9424008888888888
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# Price Multiplier
# 2050
# Wood
# Previous value: 52.264236153877825
# New value: 52.364236153877826
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2000
# Light Fuel Oil
# Previous value: 2.693101236723519
# New value: 2.793101236723519
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2000
# Natural Gas
# Previous value: 0.9372711648144444
# New value: 1.0372711648144444
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2000
# Electricity
# Previous value: 1.0000266533339215
# New value: 1.1000266533339216
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2005
# Light Fuel Oil
# Previous value: 2.7240028675071004
# New value: 2.8240028675071005
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2005
# Natural Gas
# Previous value: 0.9480259151705669
# New value: 1.0480259151705669
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2005
# Electricity
# Previous value: 0.9999323016618731
# New value: 1.0999323016618732
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2010
# Light Fuel Oil
# Previous value: 1.8228955953753319
# New value: 1.922895595375332
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2010
# Natural Gas
# Previous value: 1.007614870430962
# New value: 1.107614870430962
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2010
# Electricity
# Previous value: 1.0001051312649165
# New value: 1.1001051312649166
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2015
# Light Fuel Oil
# Previous value: 3.3954174405264723
# New value: 3.4954174405264724
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2015
# Natural Gas
# Previous value: 1.116091850343476
# New value: 1.216091850343476
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2015
# Electricity
# Previous value: 1.0000982696280991
# New value: 1.1000982696280992
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2020
# Light Fuel Oil
# Previous value: 3.733156460154209
# New value: 3.833156460154209
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2020
# Natural Gas
# Previous value: 2.6391118032927157
# New value: 2.7391118032927158
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2020
# Electricity
# Previous value: 1.0000846272891408
# New value: 1.100084627289141
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2025
# Light Fuel Oil
# Previous value: 2.9111129694204267
# New value: 3.011112969420427
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2025
# Natural Gas
# Previous value: 2.08813289059971
# New value: 2.18813289059971
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2025
# Electricity
# Previous value: 0.9999632624113476
# New value: 1.0999632624113476
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2030
# Light Fuel Oil
# Previous value: 2.7515238611652415
# New value: 2.8515238611652416
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2030
# Natural Gas
# Previous value: 1.7171117517494738
# New value: 1.817111751749474
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2030
# Electricity
# Previous value: 1.0000357323232323
# New value: 1.1000357323232324
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2035
# Light Fuel Oil
# Previous value: 2.7061741574326152
# New value: 2.8061741574326153
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2035
# Natural Gas
# Previous value: 1.5513793618632692
# New value: 1.6513793618632693
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2035
# Electricity
# Previous value: 0.9999537142857143
# New value: 1.0999537142857143
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2040
# Light Fuel Oil
# Previous value: 2.697844620012337
# New value: 2.797844620012337
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2040
# Natural Gas
# Previous value: 1.4753557448275343
# New value: 1.5753557448275344
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2040
# Electricity
# Previous value: 0.9999537142857143
# New value: 1.0999537142857143
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2045
# Light Fuel Oil
# Previous value: 2.697844620012337
# New value: 2.797844620012337
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2045
# Natural Gas
# Previous value: 1.4753557448275343
# New value: 1.5753557448275344
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2045
# Electricity
# Previous value: 0.9999537142857143
# New value: 1.0999537142857143
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2050
# Light Fuel Oil
# Previous value: 2.697844620012337
# New value: 2.797844620012337
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2050
# Natural Gas
# Previous value: 1.4753557448275343
# New value: 1.5753557448275344
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# Price Multiplier
# 2050
# Electricity
# Previous value: 0.9999537142857143
# New value: 1.0999537142857143
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2000
# Diesel
# Previous value: 3.5270176723054507
# New value: 3.627017672305451
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2000
# Gasoline
# Previous value: 3.830582153813321
# New value: 3.930582153813321
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2000
# Natural Gas
# Previous value: 0.9372711648144444
# New value: 1.0372711648144444
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2000
# Electricity
# Previous value: 3.1103008858207324
# New value: 3.2103008858207325
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2000
# Hydrogen
# Previous value: 1.0000482391555283
# New value: 1.1000482391555284
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2005
# Diesel
# Previous value: 3.5674879659544745
# New value: 3.6674879659544746
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2005
# Gasoline
# Previous value: 3.874535657598915
# New value: 3.9745356575989153
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2005
# Natural Gas
# Previous value: 0.9480259151705669
# New value: 1.0480259151705669
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2005
# Electricity
# Previous value: 1.3049238777800118
# New value: 1.404923877780012
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2005
# Hydrogen
# Previous value: 0.9999264057328152
# New value: 1.0999264057328153
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2010
# Diesel
# Previous value: 2.070803511291993
# New value: 2.170803511291993
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2010
# Gasoline
# Previous value: 2.319447059006627
# New value: 2.419447059006627
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2010
# Natural Gas
# Previous value: 1.007614870430962
# New value: 1.107614870430962
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2010
# Electricity
# Previous value: 0.8525298846520366
# New value: 0.9525298846520366
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2010
# Hydrogen
# Previous value: 0.9999994391801843
# New value: 1.0999994391801844
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2015
# Diesel
# Previous value: 4.0592049554615235
# New value: 4.159204955461523
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2015
# Gasoline
# Previous value: 4.360795369855928
# New value: 4.460795369855927
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2015
# Natural Gas
# Previous value: 1.116091850343476
# New value: 1.216091850343476
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2015
# Electricity
# Previous value: 0.7896456463029468
# New value: 0.8896456463029467
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2015
# Hydrogen
# Previous value: 1.0000552599173136
# New value: 1.1000552599173137
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2020
# Diesel
# Previous value: 4.455489882051752
# New value: 4.555489882051751
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2020
# Gasoline
# Previous value: 4.633762298790633
# New value: 4.733762298790633
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2020
# Natural Gas
# Previous value: 2.6391118032927157
# New value: 2.7391118032927158
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2020
# Electricity
# Previous value: 0.7860440310117617
# New value: 0.8860440310117617
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2020
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2025
# Diesel
# Previous value: 3.379951244145145
# New value: 3.4799512441451452
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2025
# Gasoline
# Previous value: 3.4937278965888003
# New value: 3.5937278965888004
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2025
# Natural Gas
# Previous value: 2.08813289059971
# New value: 2.18813289059971
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2025
# Electricity
# Previous value: 0.8248181053147944
# New value: 0.9248181053147944
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2025
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2030
# Diesel
# Previous value: 3.149490649022979
# New value: 3.249490649022979
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2030
# Gasoline
# Previous value: 3.2457430814350827
# New value: 3.345743081435083
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2030
# Natural Gas
# Previous value: 1.7171117517494738
# New value: 1.817111751749474
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2030
# Electricity
# Previous value: 0.868539241302763
# New value: 0.968539241302763
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2030
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2035
# Diesel
# Previous value: 3.0634187623467706
# New value: 3.1634187623467707
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2035
# Gasoline
# Previous value: 3.151341657338596
# New value: 3.251341657338596
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2035
# Natural Gas
# Previous value: 1.5513793618632692
# New value: 1.6513793618632693
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2035
# Electricity
# Previous value: 0.8738483841178476
# New value: 0.9738483841178476
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2035
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2040
# Diesel
# Previous value: 3.0217710752453795
# New value: 3.1217710752453796
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2040
# Gasoline
# Previous value: 3.102289936974736
# New value: 3.202289936974736
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2040
# Natural Gas
# Previous value: 1.4753557448275343
# New value: 1.5753557448275344
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2040
# Electricity
# Previous value: 0.8738483841178476
# New value: 0.9738483841178476
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2040
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2045
# Diesel
# Previous value: 3.0217710752453795
# New value: 3.1217710752453796
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2045
# Gasoline
# Previous value: 3.102289936974736
# New value: 3.202289936974736
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2045
# Natural Gas
# Previous value: 1.4753557448275343
# New value: 1.5753557448275344
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2045
# Electricity
# Previous value: 0.8738483841178476
# New value: 0.9738483841178476
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2045
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2050
# Diesel
# Previous value: 3.0217710752453795
# New value: 3.1217710752453796
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2050
# Gasoline
# Previous value: 3.102289936974736
# New value: 3.202289936974736
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2050
# Natural Gas
# Previous value: 1.4753557448275343
# New value: 1.5753557448275344
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2050
# Electricity
# Previous value: 0.8738483841178476
# New value: 0.9738483841178476
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# Price Multiplier
# 2050
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2000
# Diesel
# Previous value: 3.5270176723054507
# New value: 3.627017672305451
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2000
# Gasoline
# Previous value: 3.830582153813321
# New value: 3.930582153813321
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2000
# Natural Gas
# Previous value: 0.9372711648144444
# New value: 1.0372711648144444
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2000
# Electricity
# Previous value: 3.1103008858207324
# New value: 3.2103008858207325
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2000
# Hydrogen
# Previous value: 1.0000482391555283
# New value: 1.1000482391555284
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2005
# Diesel
# Previous value: 3.5674879659544745
# New value: 3.6674879659544746
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2005
# Gasoline
# Previous value: 3.874535657598915
# New value: 3.9745356575989153
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2005
# Natural Gas
# Previous value: 0.9480259151705669
# New value: 1.0480259151705669
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2005
# Electricity
# Previous value: 1.3049238777800118
# New value: 1.404923877780012
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2005
# Hydrogen
# Previous value: 0.9999264057328152
# New value: 1.0999264057328153
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2010
# Diesel
# Previous value: 2.070803511291993
# New value: 2.170803511291993
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2010
# Gasoline
# Previous value: 2.319447059006627
# New value: 2.419447059006627
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2010
# Natural Gas
# Previous value: 1.007614870430962
# New value: 1.107614870430962
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2010
# Electricity
# Previous value: 0.8525298846520366
# New value: 0.9525298846520366
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2010
# Hydrogen
# Previous value: 0.9999994391801843
# New value: 1.0999994391801844
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2015
# Diesel
# Previous value: 4.0592049554615235
# New value: 4.159204955461523
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2015
# Gasoline
# Previous value: 4.360795369855928
# New value: 4.460795369855927
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2015
# Natural Gas
# Previous value: 1.116091850343476
# New value: 1.216091850343476
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2015
# Electricity
# Previous value: 0.7896456463029468
# New value: 0.8896456463029467
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2015
# Hydrogen
# Previous value: 1.0000552599173136
# New value: 1.1000552599173137
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2020
# Diesel
# Previous value: 4.455489882051752
# New value: 4.555489882051751
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2020
# Gasoline
# Previous value: 4.633762298790633
# New value: 4.733762298790633
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2020
# Natural Gas
# Previous value: 2.6391118032927157
# New value: 2.7391118032927158
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2020
# Electricity
# Previous value: 0.7860440310117617
# New value: 0.8860440310117617
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2020
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2025
# Diesel
# Previous value: 3.379951244145145
# New value: 3.4799512441451452
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2025
# Gasoline
# Previous value: 3.4937278965888003
# New value: 3.5937278965888004
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2025
# Natural Gas
# Previous value: 2.08813289059971
# New value: 2.18813289059971
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2025
# Electricity
# Previous value: 0.8248181053147944
# New value: 0.9248181053147944
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2025
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2030
# Diesel
# Previous value: 3.149490649022979
# New value: 3.249490649022979
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2030
# Gasoline
# Previous value: 3.2457430814350827
# New value: 3.345743081435083
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2030
# Natural Gas
# Previous value: 1.7171117517494738
# New value: 1.817111751749474
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2030
# Electricity
# Previous value: 0.868539241302763
# New value: 0.968539241302763
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2030
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2035
# Diesel
# Previous value: 3.0634187623467706
# New value: 3.1634187623467707
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2035
# Gasoline
# Previous value: 3.151341657338596
# New value: 3.251341657338596
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2035
# Natural Gas
# Previous value: 1.5513793618632692
# New value: 1.6513793618632693
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2035
# Electricity
# Previous value: 0.8738483841178476
# New value: 0.9738483841178476
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2035
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2040
# Diesel
# Previous value: 3.0217710752453795
# New value: 3.1217710752453796
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2040
# Gasoline
# Previous value: 3.102289936974736
# New value: 3.202289936974736
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2040
# Natural Gas
# Previous value: 1.4753557448275343
# New value: 1.5753557448275344
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2040
# Electricity
# Previous value: 0.8738483841178476
# New value: 0.9738483841178476
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2040
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2045
# Diesel
# Previous value: 3.0217710752453795
# New value: 3.1217710752453796
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2045
# Gasoline
# Previous value: 3.102289936974736
# New value: 3.202289936974736
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2045
# Natural Gas
# Previous value: 1.4753557448275343
# New value: 1.5753557448275344
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2045
# Electricity
# Previous value: 0.8738483841178476
# New value: 0.9738483841178476
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2045
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2050
# Diesel
# Previous value: 3.0217710752453795
# New value: 3.1217710752453796
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2050
# Gasoline
# Previous value: 3.102289936974736
# New value: 3.202289936974736
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2050
# Natural Gas
# Previous value: 1.4753557448275343
# New value: 1.5753557448275344
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2050
# Electricity
# Previous value: 0.8738483841178476
# New value: 0.9738483841178476
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# Price Multiplier
# 2050
# Hydrogen
# Previous value: 1.0000525042890183
# New value: 1.1000525042890184
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2000
# Diesel
# Previous value: 1.0937770812306922
# New value: 1.1937770812306923
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2000
# Natural Gas
# Previous value: 0.8631315511914267
# New value: 0.9631315511914267
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2000
# Electricity
# Previous value: 2.023322296092747
# New value: 2.123322296092747
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2000
# Coal Sub Bituminous Western
# Previous value: 4.929896502862696
# New value: 5.029896502862695
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2005
# Diesel
# Previous value: 1.1063274803998135
# New value: 1.2063274803998136
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2005
# Natural Gas
# Previous value: 0.8730355839900825
# New value: 0.9730355839900825
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2005
# Electricity
# Previous value: 0.9736504624372635
# New value: 1.0736504624372636
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2005
# Coal Sub Bituminous Western
# Previous value: 4.225548361560456
# New value: 4.325548361560456
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2010
# Diesel
# Previous value: 0.9695627097274767
# New value: 1.0695627097274767
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2010
# Natural Gas
# Previous value: 0.9861305448354191
# New value: 1.086130544835419
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2010
# Electricity
# Previous value: 0.7370231503579953
# New value: 0.8370231503579952
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2010
# Coal Sub Bituminous Western
# Previous value: 3.026272354703567
# New value: 3.126272354703567
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# Price Multiplier
# 2015
# Diesel
# Previous value: 2.1039178190767513
# New value: 2.2039178190767514
# ...
# New value: 0.7826589101239669
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2020
# Diesel
# Previous value: 1.5437070753166857
# New value: 1.6437070753166858
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2020
# Light Fuel Oil
# Previous value: 1.5437070753166857
# New value: 1.6437070753166858
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2020
# Natural Gas
# Previous value: 2.0583601808411154
# New value: 2.1583601808411155
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2020
# Electricity
# Previous value: 0.6795452669589889
# New value: 0.7795452669589888
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2025
# Diesel
# Previous value: 1.202501516344152
# New value: 1.302501516344152
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2025
# Light Fuel Oil
# Previous value: 1.202501516344152
# New value: 1.302501516344152
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2025
# Natural Gas
# Previous value: 1.8894643767167414
# New value: 1.9894643767167415
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2025
# Electricity
# Previous value: 0.7130659574468086
# New value: 0.8130659574468085
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2030
# Diesel
# Previous value: 1.0948714186876827
# New value: 1.1948714186876828
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2030
# Light Fuel Oil
# Previous value: 1.0948714186876827
# New value: 1.1948714186876828
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2030
# Natural Gas
# Previous value: 1.562505904369732
# New value: 1.6625059043697321
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2030
# Electricity
# Previous value: 0.7508634469696969
# New value: 0.8508634469696968
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2035
# Diesel
# Previous value: 1.0087995320114744
# New value: 1.1087995320114745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2035
# Light Fuel Oil
# Previous value: 1.0087995320114744
# New value: 1.1087995320114745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2035
# Natural Gas
# Previous value: 1.4089965523614778
# New value: 1.508996552361478
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2035
# Electricity
# Previous value: 0.7554532698412698
# New value: 0.8554532698412698
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2040
# Diesel
# Previous value: 0.9662263407522744
# New value: 1.0662263407522745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2040
# Light Fuel Oil
# Previous value: 0.9662263407522744
# New value: 1.0662263407522745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2040
# Natural Gas
# Previous value: 1.3417283298616394
# New value: 1.4417283298616395
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2040
# Electricity
# Previous value: 0.7554532698412698
# New value: 0.8554532698412698
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2045
# Diesel
# Previous value: 0.9662263407522744
# New value: 1.0662263407522745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2045
# Light Fuel Oil
# Previous value: 0.9662263407522744
# New value: 1.0662263407522745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2045
# Natural Gas
# Previous value: 1.3417283298616394
# New value: 1.4417283298616395
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2045
# Electricity
# Previous value: 0.7554532698412698
# New value: 0.8554532698412698
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2050
# Diesel
# Previous value: 0.9662263407522744
# New value: 1.0662263407522745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2050
# Light Fuel Oil
# Previous value: 0.9662263407522744
# New value: 1.0662263407522745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2050
# Natural Gas
# Previous value: 1.3417283298616394
# New value: 1.4417283298616395
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Ethanol
# Price Multiplier
# 2050
# Electricity
# Previous value: 0.7554532698412698
# New value: 0.8554532698412698
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2000
# Diesel
# Previous value: 1.0937770812306922
# New value: 1.1937770812306923
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2000
# Light Fuel Oil
# Previous value: 1.0937770812306922
# New value: 1.1937770812306923
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2000
# Natural Gas
# Previous value: 0.8631315511914267
# New value: 0.9631315511914267
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2000
# Electricity
# Previous value: 0.7221624541429579
# New value: 0.8221624541429579
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2005
# Diesel
# Previous value: 1.1063274803998135
# New value: 1.2063274803998136
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2005
# Light Fuel Oil
# Previous value: 1.1063274803998135
# New value: 1.2063274803998136
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2005
# Natural Gas
# Previous value: 0.8730355839900825
# New value: 0.9730355839900825
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2005
# Electricity
# Previous value: 0.6716637169700528
# New value: 0.7716637169700528
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2010
# Diesel
# Previous value: 0.9695627097274767
# New value: 1.0695627097274767
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2010
# Light Fuel Oil
# Previous value: 0.9695627097274767
# New value: 1.0695627097274767
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2010
# Natural Gas
# Previous value: 0.9861305448354191
# New value: 1.086130544835419
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2010
# Electricity
# Previous value: 0.7370231503579953
# New value: 0.8370231503579952
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2015
# Diesel
# Previous value: 2.1039178190767513
# New value: 2.2039178190767514
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2015
# Light Fuel Oil
# Previous value: 2.1039178190767513
# New value: 2.2039178190767514
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2015
# Natural Gas
# Previous value: 1.395114812929345
# New value: 1.495114812929345
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2015
# Electricity
# Previous value: 0.682658910123967
# New value: 0.7826589101239669
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2020
# Diesel
# Previous value: 1.5437070753166857
# New value: 1.6437070753166858
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2020
# Light Fuel Oil
# Previous value: 1.5437070753166857
# New value: 1.6437070753166858
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2020
# Natural Gas
# Previous value: 2.0583601808411154
# New value: 2.1583601808411155
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2020
# Electricity
# Previous value: 0.6795452669589889
# New value: 0.7795452669589888
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2025
# Diesel
# Previous value: 1.202501516344152
# New value: 1.302501516344152
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2025
# Light Fuel Oil
# Previous value: 1.202501516344152
# New value: 1.302501516344152
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2025
# Natural Gas
# Previous value: 1.8894643767167414
# New value: 1.9894643767167415
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2025
# Electricity
# Previous value: 0.7130659574468086
# New value: 0.8130659574468085
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2030
# Diesel
# Previous value: 1.0948714186876827
# New value: 1.1948714186876828
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2030
# Light Fuel Oil
# Previous value: 1.0948714186876827
# New value: 1.1948714186876828
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2030
# Natural Gas
# Previous value: 1.562505904369732
# New value: 1.6625059043697321
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2030
# Electricity
# Previous value: 0.7508634469696969
# New value: 0.8508634469696968
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2035
# Diesel
# Previous value: 1.0087995320114744
# New value: 1.1087995320114745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2035
# Light Fuel Oil
# Previous value: 1.0087995320114744
# New value: 1.1087995320114745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2035
# Natural Gas
# Previous value: 1.4089965523614778
# New value: 1.508996552361478
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2035
# Electricity
# Previous value: 0.7554532698412698
# New value: 0.8554532698412698
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2040
# Diesel
# Previous value: 0.9662263407522744
# New value: 1.0662263407522745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2040
# Light Fuel Oil
# Previous value: 0.9662263407522744
# New value: 1.0662263407522745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2040
# Natural Gas
# Previous value: 1.3417283298616394
# New value: 1.4417283298616395
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2040
# Electricity
# Previous value: 0.7554532698412698
# New value: 0.8554532698412698
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2045
# Diesel
# Previous value: 0.9662263407522744
# New value: 1.0662263407522745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2045
# Light Fuel Oil
# Previous value: 0.9662263407522744
# New value: 1.0662263407522745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2045
# Natural Gas
# Previous value: 1.3417283298616394
# New value: 1.4417283298616395
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2045
# Electricity
# Previous value: 0.7554532698412698
# New value: 0.8554532698412698
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2050
# Diesel
# Previous value: 0.9662263407522744
# New value: 1.0662263407522745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2050
# Light Fuel Oil
# Previous value: 0.9662263407522744
# New value: 1.0662263407522745
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2050
# Natural Gas
# Previous value: 1.3417283298616394
# New value: 1.4417283298616395
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Biodiesel
# Price Multiplier
# 2050
# Electricity
# Previous value: 0.7554532698412698
# New value: 0.8554532698412698
# ------------------------------------------------------------------------------------------

# %% [markdown]
# 2. For 2025 and every year afterwards, increase the CO2 Tax at sector level nodes to a minimum of 50 (i.e. for nodes that already had a tax >= 50, no change required, otherwise, increase to 50).

# %%
relevant_years = [x for x in model.years if int(x) >= 2025]

for node in model.graph.nodes:
    if model.graph.nodes[node]['competition type'] in ['sector']:
        for year in relevant_years:
            try:
                prev_val = model.graph.nodes[node][year]['Tax']['CO2']['year_value']
                print(node)
                print('CO2 Tax')
                print(year)
                print('Previous value: ' + str(prev_val))
                model.graph.nodes[node][year]['Tax']['CO2']['year_value'] = max(50, prev_val)
                print('New value: ' + str(model.graph.nodes[node][year]['Tax']['CO2']['year_value']))
                print(dash)
            except:
                continue
# Out:
# pyCIMS.Canada.Alberta.Residential
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Residential
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Commercial
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Personal
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Transportation Freight
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Natural Gas Extraction
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Natural Gas Extraction
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Natural Gas Extraction
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Natural Gas Extraction
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Natural Gas Extraction
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Natural Gas Extraction
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Crude
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Crude
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Crude
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Crude
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Crude
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Crude
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Other Manufacturing
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Other Manufacturing
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Other Manufacturing
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Other Manufacturing
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Other Manufacturing
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Other Manufacturing
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Waste
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Waste
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Waste
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Waste
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Waste
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Waste
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Agriculture
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Agriculture
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Agriculture
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Agriculture
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Agriculture
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Agriculture
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Electricity
# CO2 Tax
# 2025
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Electricity
# CO2 Tax
# 2030
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Electricity
# CO2 Tax
# 2035
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Electricity
# CO2 Tax
# 2040
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Electricity
# CO2 Tax
# 2045
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Electricity
# CO2 Tax
# 2050
# Previous value: 0.0
# New value: 50
# ------------------------------------------------------------------------------------------

# %% [markdown]
# 3. For all nodes where their branches match the form *Pumping.Precision.Small (e.g. pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small, pyCIMS.Canada.Alberta.Pulp  Paper.Pumping.Precision.Small, pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small, etc) change the value of Heterogeneity (across all years) to 0.6.

# %%
for node in model.graph.nodes:
    if node.endswith('Pumping.Precision.Small'):
        for year in model.years:
            print(node)
            print(year)
            print('Previous value: ' + str(model.graph.nodes[node][year]['Heterogeneity'][None]['year_value']))
            model.graph.nodes[node][year]['Heterogeneity'][None]['year_value'] = 0.6
            print('New value: ' + str(model.graph.nodes[node][year]['Heterogeneity'][None]['year_value']))
            print(dash)
# Out:
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small
# 2000
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small
# 2005
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small
# 2010
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small
# 2015
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small
# 2020
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small
# 2025
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small
# 2030
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small
# 2035
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small
# 2040
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small
# 2045
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small
# 2050
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small
# 2000
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small
# 2005
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small
# 2010
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small
# 2015
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small
# 2020
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small
# 2025
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small
# 2030
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small
# 2035
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small
# 2040
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small
# 2045
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small
# 2050
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small
# 2000
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small
# 2005
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small
# 2010
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small
# 2015
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small
# 2020
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small
# 2025
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small
# 2030
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small
# 2035
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small
# 2040
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small
# 2045
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small
# 2050
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small
# 2000
# Previous value: 0.4
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small
# 2005
# Previous value: 0.4
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small
# 2010
# Previous value: 0.4
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small
# 2015
# Previous value: 0.4
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small
# 2020
# Previous value: 0.4
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small
# 2025
# Previous value: 0.4
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small
# 2030
# Previous value: 0.4
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small
# 2035
# Previous value: 0.4
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small
# 2040
# Previous value: 0.4
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small
# 2045
# Previous value: 0.4
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small
# 2050
# Previous value: 0.4
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small
# 2000
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small
# 2005
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small
# 2010
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small
# 2015
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small
# 2020
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small
# 2025
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small
# 2030
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small
# 2035
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small
# 2040
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small
# 2045
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small
# 2050
# Previous value: 10.0
# New value: 0.6
# ------------------------------------------------------------------------------------------

# %% [markdown]
# # Run the Model
# We can now run the model training after all the changes have been applied.

# %%
# run the model 
model.run(max_iterations=5, show_warnings=False)
# Out:
# ***** ***** year: 2000 ***** *****
# iter 0
# ***** ***** year: 2005 ***** *****
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# ***** ***** year: 2010 ***** *****
# iter 0
# /Users/adrienawong/Documents/SFU/consulting/pycims_prototype/pyCIMS/model.py:155: UserWarning: Max iterations reached for year 2005. Continuing to next year.
#   "Continuing to next year.".format(year))
# iter 1
# ***** ***** year: 2015 ***** *****
# iter 0
# iter 1
# ***** ***** year: 2020 ***** *****
# iter 0
# iter 1
# ***** ***** year: 2025 ***** *****
# iter 0
# iter 1
# ***** ***** year: 2030 ***** *****
# iter 0
# iter 1
# ***** ***** year: 2035 ***** *****
# iter 0
# iter 1
# ***** ***** year: 2040 ***** *****
# iter 0
# iter 1
# ***** ***** year: 2045 ***** *****
# iter 0
# iter 1
# ***** ***** year: 2050 ***** *****
# iter 0
# iter 1

# %% [markdown]
# # Double Checking the Changes
# To see whether our changes were put into effect, with code taken from the Quickstart notebook, let's look at the single-node change #1:
#
# At node pyCIMS.Canada.Alberta.Residential.Buildings.Floorspace.Lighting update the Market share in year "2000" for the Incandescent & CFL technologies to 0.8 and 0.2, respectively.
#
# The previous market share values for the year 2000 were 0.92 for Incandescent and 0.08 for CFL so we can see that the changes were correctly applied

# %%
node_of_interest = 'pyCIMS.Canada.Alberta.Residential.Buildings.Floorspace.Lighting' # Change this line to see other nodes

# Printing the Table Header
headers = ('Technology', 'New Market Share', 'Total Market Share')
dash = '-' * 70
cols = '{:<20}{:>25}{:>25}'
print("{}".format(node_of_interest))
print(dash)
print(cols.format(*headers))             
print(dash)

# Printing the Table Content
total_stocks = {}
year = '2000'
print(year)
for tech, data in model.graph.nodes[node_of_interest][year]['technologies'].items():
    n_ms = str(round(data['new_market_share']*100)) + "%"
    t_ms = str(round(data['total_market_share']*100)) + '%'      
    print(cols.format(tech, n_ms, t_ms))             
print(dash)
# Out:
# pyCIMS.Canada.Alberta.Residential.Buildings.Floorspace.Lighting
# ----------------------------------------------------------------------
# Technology                   New Market Share       Total Market Share
# ----------------------------------------------------------------------
# 2000
# Incandescent                              80%                      80%
# CFL                                       20%                      20%
# LED                                        0%                       0%
# ----------------------------------------------------------------------

# %% [markdown]
# As another example, let's look at multi-node change #3:
#
# For all nodes where their branches match the form *Pumping.Precision.Small (e.g. pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small, pyCIMS.Canada.Alberta.Pulp Paper.Pumping.Precision.Small, pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small, etc) change the value of Heterogeneity (across all years) to 0.6.
#
# We can see that all the values have been correctly changed to 0.6.

# %%
# Printing the Table Header
headers = ('Branch', 'Heterogeneity')
dash = '-' * 90
cols = '{:<65}{:>25}'
print(dash)
print(cols.format(*headers))             
print(dash)

# Printing the Table Content
total_stocks = {}
for year in model.years:
    print(year)
    for node in model.graph.nodes:
        if node.endswith('Pumping.Precision.Small'):
            h_val = model.graph.nodes[node][year]['Heterogeneity'][None]['year_value']
            print(cols.format(node, h_val))             
    print(dash)
# Out:
# ------------------------------------------------------------------------------------------
# Branch                                                                       Heterogeneity
# ------------------------------------------------------------------------------------------
# 2000
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small                              0.6
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small                       0.6
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small                      0.6
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small                        0.6
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small                           0.6
# ------------------------------------------------------------------------------------------
# 2005
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small                              0.6
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small                       0.6
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small                      0.6
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small                        0.6
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small                           0.6
# ------------------------------------------------------------------------------------------
# 2010
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small                              0.6
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small                       0.6
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small                      0.6
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small                        0.6
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small                           0.6
# ------------------------------------------------------------------------------------------
# 2015
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small                              0.6
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small                       0.6
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small                      0.6
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small                        0.6
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small                           0.6
# ------------------------------------------------------------------------------------------
# 2020
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small                              0.6
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small                       0.6
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small                      0.6
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small                        0.6
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small                           0.6
# ------------------------------------------------------------------------------------------
# 2025
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small                              0.6
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small                       0.6
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small                      0.6
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small                        0.6
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small                           0.6
# ------------------------------------------------------------------------------------------
# 2030
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small                              0.6
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small                       0.6
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small                      0.6
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small                        0.6
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small                           0.6
# ------------------------------------------------------------------------------------------
# 2035
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small                              0.6
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small                       0.6
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small                      0.6
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small                        0.6
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small                           0.6
# ------------------------------------------------------------------------------------------
# 2040
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small                              0.6
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small                       0.6
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small                      0.6
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small                        0.6
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small                           0.6
# ------------------------------------------------------------------------------------------
# 2045
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small                              0.6
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small                       0.6
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small                      0.6
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small                        0.6
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small                           0.6
# ------------------------------------------------------------------------------------------
# 2050
# pyCIMS.Canada.Alberta.Coal Mining.Pumping.Precision.Small                              0.6
# pyCIMS.Canada.Alberta.Petroleum Refining.Pumping.Precision.Small                       0.6
# pyCIMS.Canada.Alberta.Industrial Minerals.Pumping.Precision.Small                      0.6
# pyCIMS.Canada.Alberta.Chemical Products.Pumping.Precision.Small                        0.6
# pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Precision.Small                           0.6
# ------------------------------------------------------------------------------------------
