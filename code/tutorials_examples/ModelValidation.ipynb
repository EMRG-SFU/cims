# %% [markdown]
# # Model Validation Instructions
#
# This notebook serves as a more thorough introduction to pyCIMS model validation functionality. For this notebook to run properly, ensure:
# * pyCIMS is downloaded and installed on your local machine according to the [installation instructions](../../docs/Installation.md)
# * The `pyCIMS_env` conda environment has been activated according the [conda environment instructions](../../docs/WorkingWithCondaEnvironment.md)
#
# For a more general of pyCIMS, please see the [Quickstart](Quickstart.ipynb) tutorial.

# %% [markdown]
# ## Import pyCIMS  & other packages

# %%
import pyCIMS
import pprint as pp

# %% [markdown]
# Now that we have loaded `pyCIMS`, we can use the `ModelValidator`. First we will instantiate the `ModelValidator` class. To instantiate the class we must provide the location of the excel file specifying the model description.
#
# Optionally you can also provide a `node_col` parameter. This tells the model validator what the name of column specifying Node names. In the current model description (2020-09-17) this column is `"Node"`. If not provided with a value, this parameter defaults to `"Node"`.

# %% [markdown]
# ## Initialize the `ModelValidator`

# %%
model_description_file = '../../pyCIMS_model_description_Alberta_Validated.xlsb'

model_validator = pyCIMS.ModelValidator(model_description_file)

# %% [markdown]
# Next, using our `model_validator` we will use the `validate()` method to check for any errors in our model description. There are a couple of paramters for this method. I'll explain them below:
# * **`verbose`** : Determines whether the method will use print statements to notify of any problems identified in the model description. Here we have set verbose to be True so that we will see printed statements letting us know about the errors. .
#
# * **`raise_warnings`** : Determines whether the method will raise warnings when it identifies problems in the model description. Warnings are more "in your face" than print statements, appearing in red for the user. However, warnings do go away if you run the cell multiple times. Here, we have set raise_warnings to False. We will just look at the printed statements and the resulting dictionary (next cell)

# %% [markdown]
# ## Validate the model

# %%
model_validator.validate(verbose=True, raise_warnings=False)
# Out:
# 0 node name/branch mismatches.
# 0 references to unspecified nodes.
# 0 non-root nodes are never referenced.
# 0 nodes were specified but don't provide a service.
# 0 nodes had invalid competition types.
# 2 nodes requested services of themselves. See ModelValidator.warnings['nodes_requesting_self'] for more info
# 139 nodes or technologies don't request other services. See ModelValidator.warnings['nodes_no_requested_service'] for more info

# %% [markdown]
# ## Investigate the Warnings

# %% [markdown]
# Regardless of whether you use the `verbose` or `raise_warnings` options in the `validate()` method call, any problems identified can be accessed through the `ModelValidator.warnings` attribute.

# %%
pp.pprint(model_validator.warnings)
# Out:
# {'nodes_no_requested_service': [(44391, 'Aviation Turbo Fuel'),
#                                 (44399, 'Black Liquor'),
#                                 (44407, 'Byproduct Gas'),
#                                 (44415, 'Coal Sub Bituminous Western'),
#                                 (44423, 'Coke'),
#                                 (44431, 'Diesel'),
#                                 (44439, 'Diesel Marine'),
#                                 (44447, 'Diesel Rail'),
#                                 (44455, 'Diesel Road'),
#                                 (44463, 'Gasoline'),
#                                 (44471, 'Geothermal'),
#                                 (44479, 'Heavy Fuel Oil'),
#                                 (44487, 'Hog Fuel'),
#                                 (44503, 'Light Fuel Oil'),
#                                 (44519, 'Petroleum Coke'),
#                                 (44527, 'Propane'),
#                                 (44535, 'Propane Solvent'),
#                                 (44543, 'Solar'),
#                                 (44559, 'Uranium'),
#                                 (44567, 'Walking'),
#                                 (44575, 'Water'),
#                                 (44583, 'Wind'),
#                                 (44591, 'Wood'),
#                                 (2451, 'No AC', 'Existing'),
#                                 (12952,
#                                  'Direct Drive Small',
#                                  'Process_heaters_Boilers'),
#                                 (12952,
#                                  'Direct Drive Small',
#                                  'Reciprocating_compressor_engine_w_lean_burn_retro'),
#                                 (12952,
#                                  'Direct Drive Small',
#                                  'Reciprocating_compressor_engine_electric'),
#                                 (13313, 'CCS', 'CCS'),
#                                 (1762, 'Minor Appliances', 'New w PV panels'),
#                                 (7063, 'Rapid Bus', 'Rapid Transit Light Rail'),
#                                 (7063, 'Rapid Bus', 'Rapid Transit Heavy Rail'),
#                                 (7063,
#                                  'Rapid Bus',
#                                  'Rapid Transit Commuter Train'),
#                                 (41111,
#                                  'Medium Sites',
#                                  'Medium_Sites_No_Control'),
#                                 (41111, 'Medium Sites', 'Medium_Sites_Flaring'),
#                                 (41111,
#                                  'Medium Sites',
#                                  'Medium_Sites_Electricity_Generation'),
#                                 (41111,
#                                  'Medium Sites',
#                                  'Medium_Sites_Flaring_>_2011'),
#                                 (41111,
#                                  'Medium Sites',
#                                  'Medium_Sites_Electricity_Generation_>_2011'),
#                                 (41444, 'Soils', 'Agroforestry'),
#                                 (41444, 'Soils', 'Agroforestry'),
#                                 (27641,
#                                  'Unassigned Emissions',
#                                  'CAC_Emissions'),
#                                 (13043,
#                                  'Direct Drive Large',
#                                  'Process_heaters_Boilers'),
#                                 (13043,
#                                  'Direct Drive Large',
#                                  'Gas_turbine_w_improved_Eff_available_in_2000'),
#                                 (13043,
#                                  'Direct Drive Large',
#                                  'Gas_turbine_w_improved_Eff_available_in_2010'),
#                                 (13043,
#                                  'Direct Drive Large',
#                                  'Gas_turbine_w_improved_Eff_available_in_2020'),
#                                 (13043,
#                                  'Direct Drive Large',
#                                  'Gas_turbine_w_improved_Eff_available_in_2030'),
#                                 (13043,
#                                  'Direct Drive Large',
#                                  'Std_AC_induction_motor_500_hp_CENG_LG_ELEC'),
#                                 (13043,
#                                  'Direct Drive Large',
#                                  'Eff_AC_induction_motor_500_hp_CENG_LG_ELEC_EFF'),
#                                 (13250, 'Formation CO2', 'No_Formation_CCS'),
#                                 (6783, 'Standard Emissions', 'Bus Urban Gas'),
#                                 (6783,
#                                  'Standard Emissions',
#                                  'Bus Urban Diesel Existing'),
#                                 (6783, 'Standard Emissions', 'Bus Urban NG'),
#                                 (6783,
#                                  'Standard Emissions',
#                                  'Bus Urban Propane'),
#                                 (6783,
#                                  'Standard Emissions',
#                                  'Seabus Ferry Urban'),
#                                 (6783,
#                                  'Standard Emissions',
#                                  'Bus Urban Electric Hybrid'),
#                                 (38756,
#                                  'Direct',
#                                  'Std_heat_system_fueled_by_NG'),
#                                 (38756,
#                                  'Direct',
#                                  'Eff_heat_system_fueled_by_NG'),
#                                 (38756,
#                                  'Direct',
#                                  'Std_heat_system_fueled_by_oil'),
#                                 (38756,
#                                  'Direct',
#                                  'Std_heat_system_fueled_by_heavy_oil'),
#                                 (38756,
#                                  'Direct',
#                                  'Std_direct_heat_fueled_by_electricity'),
#                                 (38756,
#                                  'Direct',
#                                  'Eff_direct_heat_fueled_by_electricity'),
#                                 (38756,
#                                  'Direct',
#                                  'Std_direct_heat_fueled_by_wood_waste'),
#                                 (38756,
#                                  'Direct',
#                                  'Eff_direct_heat_fueled_by_wood_waste'),
#                                 (6033,
#                                  'Motive Power',
#                                  'Motive_Power_Low_efficiency'),
#                                 (6033,
#                                  'Motive Power',
#                                  'Motive_Power_High_efficiency'),
#                                 (12887,
#                                  'Direct Heat Production',
#                                  'Process_heaters_Boilers'),
#                                 (38584,
#                                  'Ventilation AC',
#                                  'HVAC_System_for_Lg_old_shell'),
#                                 (38584,
#                                  'Ventilation AC',
#                                  'HVAC_System_for_Lg_new_shell_powered_by_electricity_only'),
#                                 (38584,
#                                  'Ventilation AC',
#                                  'HVAC_System_for_Lg_new_shell_powered_by_electricity_and_NG'),
#                                 (38584,
#                                  'Ventilation AC',
#                                  'HVAC_System_for_Lg_high_Eff_shell_powered_by_NG_and_electricity'),
#                                 (38584,
#                                  'Ventilation AC',
#                                  'HVAC_System_for_super_efficiencey_shell_fired_by_NG'),
#                                 (38584,
#                                  'Ventilation AC',
#                                  'HVAC_System_for_super_Eff_shell'),
#                                 (15002, 'Cogenerators', 'COG_OIL'),
#                                 (15002, 'Cogenerators', 'COG_HFO_III'),
#                                 (15002, 'Cogenerators', 'COG_NGT_40H'),
#                                 (15002, 'Cogenerators', 'COG_NGT_10H'),
#                                 (15002, 'Cogenerators', 'COG_NGT_40L'),
#                                 (15002, 'Cogenerators', 'COG_NGT_10L'),
#                                 (15002,
#                                  'Cogenerators',
#                                  'Cogenerators_heavy_fuel_oil_steam_turbine_1250_psig'),
#                                 (15002,
#                                  'Cogenerators',
#                                  'NG_Turbine_Cogen_w_Heat_Recovery_Steam_Generator_40_MW_High_H_P_ratio'),
#                                 (15002,
#                                  'Cogenerators',
#                                  'NG_Turbine_Cogen_w_Heat_Recover_Steam_Generator_10_MW_High_H_P_Ratio'),
#                                 (15002,
#                                  'Cogenerators',
#                                  'NG_Turbine_Cogen_w_Heat_Recovery_Steam_Generator_40_MW_Low_H_P_ratio'),
#                                 (15002,
#                                  'Cogenerators',
#                                  'NG_Turbine_Cogen_w_Heat_Recovery_Steam_Generator_10_MW_Low_H_P_ratio'),
#                                 (15002,
#                                  'Cogenerators',
#                                  'Back_Pressure_Steam_Turbine_w_NGl_Boilers_turbine_inlet_pressure_1250_psi_30_MW'),
#                                 (15002,
#                                  'Cogenerators',
#                                  'Spark_Ignition_Reciprocating_engine_NG_6MW'),
#                                 (14741, 'Boilers', 'Boilers_NG_600_psig'),
#                                 (14741,
#                                  'Boilers',
#                                  'Boilers_NG_600_psig_w_heat_recovery'),
#                                 (14741,
#                                  'Boilers',
#                                  'Boilers_NG_600_psig_w_regenerative_burners'),
#                                 (14741,
#                                  'Boilers',
#                                  'Boilers_NG_600_psig_w_heat_recovery_and_regenerative_burners'),
#                                 (14741,
#                                  'Boilers',
#                                  'Boilers_low_sulfur_residual_600_psig'),
#                                 (14741, 'Boilers', 'Boilers_Electric'),
#                                 (14741,
#                                  'Boilers',
#                                  'Boilers_Hydrogen_600_psig_w_heat_recovery_and_regenerative_burners'),
#                                 (14741, 'Boilers', 'Boilers_NG_600_psig_2025'),
#                                 (14741, 'Boilers', 'Eff_hot_water_Boilers_NG'),
#                                 (14741,
#                                  'Boilers',
#                                  'High_Eff_hot_water_Boilers_NG'),
#                                 (14741,
#                                  'Boilers',
#                                  'Std_hot_water_Boilers_electric'),
#                                 (14741,
#                                  'Boilers',
#                                  'Eff_hot_water_Boilers_electric'),
#                                 (14741,
#                                  'Boilers',
#                                  'High_Eff_hot_water_Boilers_electric'),
#                                 (156, 'Solar electricity', 'No Solar'),
#                                 (156, 'Solar electricity', 'Solar PV'),
#                                 (10349, 'Space Heating', 'Space_heat_NG_Eff'),
#                                 (10349, 'Space Heating', 'Space_heat_NG_Eff'),
#                                 (10349,
#                                  'Space Heating',
#                                  'Space_heat_electric_Eff'),
#                                 (11893, 'Size 1', 'AC_motor_1_5_hp'),
#                                 (11893, 'Size 1', 'Eff_AC_motor_1_5_hp'),
#                                 (2662, 'Air dry', 'Air dry clothes'),
#                                 (12451,
#                                  'Drilling',
#                                  'Exploration_and_drilling_of_new_gas_wells'),
#                                 (12451,
#                                  'Drilling',
#                                  'Exploration_and_drilling_of_new_gas_wells_efficient_w_ELDAR'),
#                                 (43299,
#                                  'Transmission Losses',
#                                  'Transmission Losses'),
#                                 (6977,
#                                  'Zero Emissions',
#                                  'Bus Urban Hybrid Biodiesel'),
#                                 (6977, 'Zero Emissions', 'Bus Urban Hydrogen'),
#                                 (38976,
#                                  'Indirect',
#                                  'Std_indirect_heat_fueled_by_electricity'),
#                                 (38976,
#                                  'Indirect',
#                                  'Eff_indirect_heat_fueled_by_electricity'),
#                                 (40972,
#                                  'Small Sites',
#                                  'Small_Sites_No_Control'),
#                                 (40972, 'Small Sites', 'Small_Sites_Flaring'),
#                                 (40972,
#                                  'Small Sites',
#                                  'Small_Sites_Electricity_Generation'),
#                                 (40972,
#                                  'Small Sites',
#                                  'Small_Sites_Flaring_>_2011'),
#                                 (40972,
#                                  'Small Sites',
#                                  'Small_Sites_Electricity_Generation_>_2011'),
#                                 (41250,
#                                  'Large Sites',
#                                  'Large_Sites_No_Control'),
#                                 (41250, 'Large Sites', 'Large_Sites_Flaring'),
#                                 (41250,
#                                  'Large Sites',
#                                  'Large_Sites_Electricity_Generation'),
#                                 (41250,
#                                  'Large Sites',
#                                  'Large_Sites_Flaring_>_2011'),
#                                 (41250,
#                                  'Large Sites',
#                                  'Large_Sites_Electricity_Generation_>_2011'),
#                                 (67,
#                                  'Lighting',
#                                  'Base_Lighting_assumes_INC_0_4_FL_T12_66_MV_1_8_LPS_0_HPS_7_MH_26_of_Floor_Space'),
#                                 (67,
#                                  'Lighting',
#                                  'More_Eff_Lighting_same_lighting_type_ratios_between_HID_other_but_T8_instead_of_T12_and_all_MH_instead_of_MV'),
#                                 (67,
#                                  'Lighting',
#                                  'Base_Lighting_assumes_INC_0_4_FL_T12_66_MV_1_8_LPS_0_HPS_7_MH_26_of_Floor_Space'),
#                                 (67,
#                                  'Lighting',
#                                  'More_Eff_Lighting_same_lighting_type_ratios_between_HID_other_but_T8_instead_of_T12_and_all_MH_instead_of_MV'),
#                                 (67,
#                                  'Lighting',
#                                  'Base_Lighting_assumes_INC_0_4_FL_T12_66_MV_1_8_LPS_0_HPS_7_MH_26_of_Floor_Space_OM_LIGHT'),
#                                 (67,
#                                  'Lighting',
#                                  'More_Eff_Lighting_same_lighting_type_ratios_between_HID_other_but_T8_instead_of_T12_and_all_MH_instead_of_MV_OM_LIGHT_EF1'),
#                                 (67,
#                                  'Lighting',
#                                  'More_Eff_Lighting_same_lighting_type_ratios_between_HID_other_but_Super_T8_instead_of_T8_and_Highbay_Fluorescent_instead_of_Metal_Halide_OM_LIGHT_EF2'),
#                                 (11954, 'Size 2', 'AC_motor_6_25_hp'),
#                                 (11954, 'Size 2', 'Eff_motor_6_25_hp'),
#                                 (23995,
#                                  'Burners',
#                                  'Burner_natural_gas_standard'),
#                                 (23995,
#                                  'Burners',
#                                  'Burner_natural_gas_efficient'),
#                                 (23995,
#                                  'Burners',
#                                  'Burner_heavy_fuel_oil_standard'),
#                                 (23995,
#                                  'Burners',
#                                  'Burner_heavy_fuel_oil_efficient'),
#                                 (23995, 'Burners', 'Burner_coke_standard'),
#                                 (23995,
#                                  'Burners',
#                                  'Burner_hazardous_waste_standard'),
#                                 (23995,
#                                  'Burners',
#                                  'Burner_waste_fuel_standard'),
#                                 (23995,
#                                  'Burners',
#                                  'Burner_hydrogen_efficient')],
#  'nodes_requesting_self': [(12949,
#                             'pyCIMS.Canada.Alberta.Natural Gas '
#                             'Extraction.Direct Heat Production'),
#                            (15828,
#                             'pyCIMS.Canada.Alberta.Petroleum Crude.CCS')]}

# %% [markdown]
# Ideally the code above returned an empty dictionary. If not, the examples below should help explain what the `warnings` dictionary might contain.
#
# First off, the `warnings` dictionary can contain up to 7 keys (as of September 2020). These 7 keys are:
# * [`mismatched_node_names`](#mismatch)
# * [`unspecified_nodes`](#unspecified)
# * [`unreferenced_nodes`](#unreferenced)
# * [`nodes_no_provided_service`](#no_provided_services)
# * [`nodes_no_requested_service`](#no_requested_services)
# * [`invalid_competition_type`](#comp)
# * [`nodes_requesting_self`](#self)
#
# See the sections below for more information on what each of these keys mean.

# %% [markdown]
# ### Node Name & Node Branch Mismatch <a id="mismatch"></a>
# This indicates a node where the node's name and the last element in the node's branch do not match. This is usually the result of a simple typo related to capitalization, white space, or extra characters.
# ```
# 'mismatched_node_names': [(16, 'Albertas', 'Alberta'),
#                           (16, 'Space heating', 'Space Heating')]
# ```
#
# Each list item indicates a mismatched node and branch name. The tuple contains (1) the row in the Excel file where the mismatch has occurred, (2) the name given to the node in the "Node" column, and (3) the name of the node according to the "Service provided" branch structure.

# %% [markdown]
# ### Unspecified Nodes <a id="unspecified"></a>
# This indicates a node which is referenced in another node's "service requested" row, but is not specified within the model description. This typically happens because of a typo in the "service requested" row's branch name. For example, in the example below, the branch name in row 49 likely should have been `pyCIMS.Canada.Alberta.Residential.Buildings.Shell` but an extra `s` was added.
#
# ```
# 'unspecified_nodes': [(49, 'pyCIMS.Canada.Alberta.Residential.Buildings.Shells'),
#                       (59, 'pyCIMS.Canada.Alberta.Residential.Buildings.Shells'),
#                       (286, 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space heating.Furnace')]
# ```
#
# Each list item indicates a service being requested from a node that was never specified in the model description. The tuple contains (1) the row in the Excel file where the reference is made, and (2) the node from which a service is being requested.

# %% [markdown]
# ### Unreferenced Nodes <a id="unreferenced"></a>
# This indicates a node which has been specified in the model description, but has not been requested by another node. This typically happens when the path to the node is incorrectly specified or contains a typo.
#
# ```
# 'unreferenced_nodes': [(289, 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space heating.Furnaces')]
# ```
#
# Each list item indicates a node specified in the model description but not requested by another node. The tuple contains (1) the row in the Excel file where the node was specified and (2) the name of the node in branch form.

# %% [markdown]
# ### Nodes which don't Provide Services<a id="no_provided_services"></a>
# This indicates a _non-root_ node which has been specified in the model description, but doesn't have a "service provided" line.
#
# ```
#  'nodes_no_provided_service': [(873, 'pyCIMS.Canada.Alberta.Commercial')]
#
# ```
# Each list item indicates a node specified in the model description which does not provide a service. The associated tuple contains (1) the row in the Excel file where the node was specified and (2) the name of the node.

# %% [markdown]
# ### Nodes & Technologies which don't Request Services<a id="no_requested_services"></a>
# This indicates a node or technology which has been specified in the model description but doesn't request services from other nodes. This won't necessarily raise errors if you were to run the model, but these nodes and technologies should be checked to ensure there isn't a missing service request line.
#
# ```
#  'nodes_no_requested_service': [(44391, 'Aviation Turbo Fuel'),
#                                 (44399, 'Black Liquor'),
#                                 (2451, 'No AC', 'Existing')]
#
# ```
#
# Each list item indicates a node or technology which doesn't request services from other nodes. The associated tuple contains (1) the row in the Excel file where the node or technology was specified, (2) the name of the node, and optionally (3) the name of the technology. The name of the technology is only included when it is a technology, rather than a node, that doesn't request a service.

# %% [markdown]
# ### Invalid Competition Type <a id="comp"></a>
# This indicates a node which has been specified in the model description, but was assigned in invalid competition type. The only valid competition types for nodes are Root, Region, Sector, Sector No Tech, Tech Compete, and Fixed Ratio. Please note, Fixed Market Share is no longer a valid competition type.
#
# ```
#  'invalid_competition_type': [(57, 'Buildings'),
#                               (2146, 'Dishwashing'),
#                               (2487, 'Clothes drying')]
# ```
#
# Each list item indicates a node with an invalid competition type. The associated tuple contains (1) the row in the Excel file where the incorrect competition type was specified and (2) the name of the node.

# %% [markdown]
# ### Nodes Requesting Self <a id="self"></a>
# This indicates a node which has been specified in the model description to request services of itself.
#
# ```
# 'nodes_requesting_self': [(36, 'pyCIMS.Canada.Alberta')]
# ```
#
# Each list item indicates a node which requests services of itself. The associated tuple contains (1) the row in the Excel file where the self service request is being made and (2) the name of the node making this service request.

# %% [markdown]
# # All the Code
# Below, I've grouped together all the code needed for validating the model description.

# %%
import pprint as pp
import pyCIMS

model_description_file = '../../pyCIMS_model_description_Alberta_Validated.xlsb'
model_description_file = '../../model_descriptions/pyCIMS_model_description.xlsm'

model_validator = pyCIMS.ModelValidator(model_description_file)
model_validator.validate(verbose=True, raise_warnings=False)
print("Problems\n********")
pp.pprint(model_validator.warnings)
# Out:
# 1 node name/branch mismatches. See ModelValidator.warnings['mismatched_node_names'] for more info
# 110 references to unspecified nodes. See ModelValidator.warnings['unspecified_nodes'] for more info
# 53 non-root nodes are never referenced. See ModelValidator.warnings['unreferenced_nodes'] for more info
# 0 nodes were specified but don't provide a service.
# 33 nodes had invalid competition types. See ModelValidator.warnings['invalid_competition_type'] for more info
# 1 nodes requested services of themselves. See ModelValidator.warnings['nodes_requesting_self'] for more info
# 10 nodes or technologies don't request other services. See ModelValidator.warnings['nodes_no_requested_service'] for more info
# Problems
# ********
# {'invalid_competition_type': [(57, 'Buildings'),
#                               (2146, 'Dishwashing'),
#                               (2487, 'Clothes drying'),
#                               (6830, 'Pumping'),
#                               (6838, 'General'),
#                               (7035, 'Slurry Stock'),
#                               (7172, 'Precision'),
#                               (7374, 'Machine Drive'),
#                               (8691, 'Pumping'),
#                               (8699, 'General'),
#                               (8896, 'Slurry Stock'),
#                               (9033, 'Precision'),
#                               (9170, 'Machine Drive'),
#                               (10696, 'Pumping'),
#                               (10704, 'General'),
#                               (10901, 'Slurry Stock'),
#                               (11038, 'Precision'),
#                               (11240, 'Machine Drive'),
#                               (12766, 'Pumping'),
#                               (12774, 'General'),
#                               (12971, 'Slurry Stock'),
#                               (13108, 'Precision'),
#                               (13310, 'Machine Drive'),
#                               (14836, 'Pumping'),
#                               (14844, 'General'),
#                               (15041, 'Slurry Stock'),
#                               (15178, 'Precision'),
#                               (15380, 'Machine Drive'),
#                               (16906, 'Pumping'),
#                               (16914, 'General'),
#                               (17111, 'Slurry Stock'),
#                               (17248, 'Precision'),
#                               (17450, 'Machine Drive')],
#  'mismatched_node_names': [(268, 'Space heating', 'Space Heating')],
#  'nodes_no_requested_service': [(18420, 'Natural Gas'),
#                                 (18426, 'Ethanol'),
#                                 (18432, 'Biodiesel'),
#                                 (18438, 'Solar'),
#                                 (18444, 'Wind'),
#                                 (18450, 'Water'),
#                                 (2681, 'Air dry', 'Hot water'),
#                                 (886, 'No AC', 'Existing'),
#                                 (18385,
#                                  'Transmission Losses',
#                                  'Transmission Losses'),
#                                 (1700, 'Solar Electricity', 'No Solar')],
#  'nodes_requesting_self': [(36, 'pyCIMS.Canada.Alberta')],
#  'unreferenced_nodes': [(269,
#                          'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                          'Heating'),
#                         (335,
#                          'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                          'heating.Furnace'),
#                         (621,
#                          'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                          'heating.Furnace.Furnace Fan'),
#                         (2717,
#                          'pyCIMS.Canada.Alberta.Residential.Buildings.Minor '
#                          'appliances'),
#                         (5961, 'pyCIMS.Canada.Alberta.Coal Mining.Conveyance'),
#                         (6206, 'pyCIMS.Canada.Alberta.Coal Mining.Compression'),
#                         (6583,
#                          'pyCIMS.Canada.Alberta.Coal Mining.Fans and blowers'),
#                         (6828, 'pyCIMS.Canada.Alberta.Coal Mining.Pumping'),
#                         (6843,
#                          'pyCIMS.Canada.Alberta.Coal '
#                          'Mining.Pumping.General.Small'),
#                         (7040,
#                          'pyCIMS.Canada.Alberta.Coal Mining.Pumping.Slurry '
#                          'Stock.Small'),
#                         (7177,
#                          'pyCIMS.Canada.Alberta.Coal '
#                          'Mining.Pumping.Precision.Small'),
#                         (7307,
#                          'pyCIMS.Canada.Alberta.Coal Mining.Direct Drive'),
#                         (8067,
#                          'pyCIMS.Canada.Alberta.Petroleum '
#                          'Refining.Compression'),
#                         (8444,
#                          'pyCIMS.Canada.Alberta.Petroleum Refining.Fans and '
#                          'blowers'),
#                         (8689,
#                          'pyCIMS.Canada.Alberta.Petroleum Refining.Pumping'),
#                         (8704,
#                          'pyCIMS.Canada.Alberta.Petroleum '
#                          'Refining.Pumping.General.Small'),
#                         (8901,
#                          'pyCIMS.Canada.Alberta.Petroleum '
#                          'Refining.Pumping.Slurry Stock.Small'),
#                         (9038,
#                          'pyCIMS.Canada.Alberta.Petroleum '
#                          'Refining.Pumping.Precision.Small'),
#                         (9827,
#                          'pyCIMS.Canada.Alberta.Industrial '
#                          'Minerals.Conveyance'),
#                         (10072,
#                          'pyCIMS.Canada.Alberta.Industrial '
#                          'Minerals.Compression'),
#                         (10449,
#                          'pyCIMS.Canada.Alberta.Industrial Minerals.Fans and '
#                          'blowers'),
#                         (10694,
#                          'pyCIMS.Canada.Alberta.Industrial Minerals.Pumping'),
#                         (10709,
#                          'pyCIMS.Canada.Alberta.Industrial '
#                          'Minerals.Pumping.General.Small'),
#                         (10906,
#                          'pyCIMS.Canada.Alberta.Industrial '
#                          'Minerals.Pumping.Slurry Stock.Small'),
#                         (11043,
#                          'pyCIMS.Canada.Alberta.Industrial '
#                          'Minerals.Pumping.Precision.Small'),
#                         (11173,
#                          'pyCIMS.Canada.Alberta.Industrial Minerals.Direct '
#                          'Drive'),
#                         (11897,
#                          'pyCIMS.Canada.Alberta.Chemical Products.Conveyance'),
#                         (12142,
#                          'pyCIMS.Canada.Alberta.Chemical Products.Compression'),
#                         (12519,
#                          'pyCIMS.Canada.Alberta.Chemical Products.Fans and '
#                          'blowers'),
#                         (12764,
#                          'pyCIMS.Canada.Alberta.Chemical Products.Pumping'),
#                         (12779,
#                          'pyCIMS.Canada.Alberta.Chemical '
#                          'Products.Pumping.General.Small'),
#                         (12976,
#                          'pyCIMS.Canada.Alberta.Chemical '
#                          'Products.Pumping.Slurry Stock.Small'),
#                         (13113,
#                          'pyCIMS.Canada.Alberta.Chemical '
#                          'Products.Pumping.Precision.Small'),
#                         (13243,
#                          'pyCIMS.Canada.Alberta.Chemical Products.Direct '
#                          'Drive'),
#                         (13967,
#                          'pyCIMS.Canada.Alberta.Pulp and Paper.Conveyance'),
#                         (14212,
#                          'pyCIMS.Canada.Alberta.Pulp and Paper.Compression'),
#                         (14589,
#                          'pyCIMS.Canada.Alberta.Pulp and Paper.Fans and '
#                          'blowers'),
#                         (14834, 'pyCIMS.Canada.Alberta.Pulp and Paper.Pumping'),
#                         (14849,
#                          'pyCIMS.Canada.Alberta.Pulp and '
#                          'Paper.Pumping.General.Small'),
#                         (15046,
#                          'pyCIMS.Canada.Alberta.Pulp and Paper.Pumping.Slurry '
#                          'Stock.Small'),
#                         (15183,
#                          'pyCIMS.Canada.Alberta.Pulp and '
#                          'Paper.Pumping.Precision.Small'),
#                         (15313,
#                          'pyCIMS.Canada.Alberta.Pulp and Paper.Direct Drive'),
#                         (16037,
#                          'pyCIMS.Canada.Alberta.Other '
#                          'Manufacturing.Conveyance'),
#                         (16282,
#                          'pyCIMS.Canada.Alberta.Other '
#                          'Manufacturing.Compression'),
#                         (16659,
#                          'pyCIMS.Canada.Alberta.Other Manufacturing.Fans and '
#                          'blowers'),
#                         (16904,
#                          'pyCIMS.Canada.Alberta.Other Manufacturing.Pumping'),
#                         (16919,
#                          'pyCIMS.Canada.Alberta.Other '
#                          'Manufacturing.Pumping.General.Small'),
#                         (17116,
#                          'pyCIMS.Canada.Alberta.Other '
#                          'Manufacturing.Pumping.Slurry Stock.Small'),
#                         (17253,
#                          'pyCIMS.Canada.Alberta.Other '
#                          'Manufacturing.Pumping.Precision.Small'),
#                         (17383,
#                          'pyCIMS.Canada.Alberta.Other Manufacturing.Direct '
#                          'Drive'),
#                         (18089, 'pyCIMS.Canada.Alberta.Waste'),
#                         (18427, 'pyCIMS.Canada.Alberta.Ethanol'),
#                         (18433, 'pyCIMS.Canada.Alberta.Biodiesel')],
#  'unspecified_nodes': [(33, 'pyCIMS.Canada.Alberta.Iron and Steel'),
#                        (34, 'pyCIMS.Canada.Alberta.Metal Smelting'),
#                        (68,
#                         'pyCIMS.Canada.Alberta.Residential.Buildings.Other '
#                         'appliances'),
#                        (80,
#                         'pyCIMS.Canada.Alberta.Residential.Buildings.Other '
#                         'appliances'),
#                        (92,
#                         'pyCIMS.Canada.Alberta.Residential.Buildings.Other '
#                         'appliances'),
#                        (104,
#                         'pyCIMS.Canada.Alberta.Residential.Buildings.Other '
#                         'appliances'),
#                        (141,
#                         'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                         'heating'),
#                        (172,
#                         'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                         'heating'),
#                        (203,
#                         'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                         'heating'),
#                        (234,
#                         'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                         'heating'),
#                        (265,
#                         'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                         'heating'),
#                        (332, 'pyCIMS.Canada.Alberta.Furnace'),
#                        (369, 'pyCIMS.Canada.Alberta.Furnace Fan'),
#                        (400, 'pyCIMS.Canada.Alberta.Furnace Fan'),
#                        (431, 'pyCIMS.Canada.Alberta.Furnace Fan'),
#                        (462, 'pyCIMS.Canada.Alberta.Furnace Fan'),
#                        (492, 'pyCIMS.Canada.Alberta.Light Fuel Oil'),
#                        (493, 'pyCIMS.Canada.Alberta.Furnace Fan'),
#                        (523, 'pyCIMS.Canada.Alberta.Light Fuel Oil'),
#                        (524, 'pyCIMS.Canada.Alberta.Furnace Fan'),
#                        (554, 'pyCIMS.Canada.Alberta.Wood'),
#                        (555, 'pyCIMS.Canada.Alberta.Furnace Fan'),
#                        (586, 'pyCIMS.Canada.Alberta.Furnace Fan'),
#                        (618, 'pyCIMS.Canada.Alberta.Furnace Fan'),
#                        (962, 'pyCIMS.Canada.Alberta.Light Fuel Oil'),
#                        (1508, 'pyCIMS.Canada.Alberta.Diesel'),
#                        (2876, 'pyCIMS.Canada.Alberta.Buildings.Water heating'),
#                        (2906, 'pyCIMS.Canada.Alberta.Buildings.Water heating'),
#                        (5049, 'pyCIMS.Canada.Alberta.Propane'),
#                        (5375, 'pyCIMS.Canada.Alberta.Light Fuel Oil'),
#                        (5407, 'pyCIMS.Canada.Alberta.Light Fuel Oil'),
#                        (5439, 'pyCIMS.Canada.Alberta.Light Fuel Oil'),
#                        (5471, 'pyCIMS.Canada.Alberta.Light Fuel Oil'),
#                        (5900, 'pyCIMS.Canada.Alberta.Transportation Personal.'),
#                        (5901, 'pyCIMS.Canada.Alberta.Transportation Personal.'),
#                        (5902, 'pyCIMS.Canada.Alberta.Transportation Personal.'),
#                        (5903, 'pyCIMS.Canada.Alberta.Transportation Personal.'),
#                        (5904, 'pyCIMS.Canada.Alberta.Transportation Personal.'),
#                        (5918,
#                         'pyCIMS.Canada.Alberta.Transportation '
#                         'Freight.Transportation Demand'),
#                        (5919,
#                         'pyCIMS.Canada.Alberta.Transportation Freight.TKT from '
#                         'rail'),
#                        (5920,
#                         'pyCIMS.Canada.Alberta.Transportation Freight.CAC '
#                         'control'),
#                        (5921,
#                         'pyCIMS.Canada.Alberta.Transportation Freight.Freight '
#                         'Truck Motors'),
#                        (5922,
#                         'pyCIMS.Canada.Alberta.Transportation Freight.Diesel '
#                         'Fuel Service'),
#                        (5936, 'pyCIMS.Canada.Alberta.Mining.'),
#                        (5937, 'pyCIMS.Canada.Alberta.Mining.'),
#                        (5938, 'pyCIMS.Canada.Alberta.Mining.'),
#                        (5939, 'pyCIMS.Canada.Alberta.Mining.'),
#                        (5940, 'pyCIMS.Canada.Alberta.Mining.'),
#                        (5954, 'pyCIMS.Canada.Alberta.Coal Mining.'),
#                        (5955, 'pyCIMS.Canada.Alberta.Coal Mining.'),
#                        (5956, 'pyCIMS.Canada.Alberta.Coal Mining.'),
#                        (5957, 'pyCIMS.Canada.Alberta.Coal Mining.'),
#                        (5958, 'pyCIMS.Canada.Alberta.Coal Mining.'),
#                        (7825, 'pyCIMS.Canada.Alberta.Coal Mining.Steam'),
#                        (8010, 'pyCIMS.Canada.Alberta.Coal Mining.Steam'),
#                        (8024, 'pyCIMS.Canada.Alberta.Natural Gas Extraction.'),
#                        (8025, 'pyCIMS.Canada.Alberta.Natural Gas Extraction.'),
#                        (8026, 'pyCIMS.Canada.Alberta.Natural Gas Extraction.'),
#                        (8027, 'pyCIMS.Canada.Alberta.Natural Gas Extraction.'),
#                        (8028, 'pyCIMS.Canada.Alberta.Natural Gas Extraction.'),
#                        (8042, 'pyCIMS.Canada.Alberta.Petroleum Crude.'),
#                        (8043, 'pyCIMS.Canada.Alberta.Petroleum Crude.'),
#                        (8044, 'pyCIMS.Canada.Alberta.Petroleum Crude.'),
#                        (8045, 'pyCIMS.Canada.Alberta.Petroleum Crude.'),
#                        (8046, 'pyCIMS.Canada.Alberta.Petroleum Crude.'),
#                        (8060, 'pyCIMS.Canada.Alberta.Petroleum Refining.'),
#                        (8061, 'pyCIMS.Canada.Alberta.Petroleum Refining.'),
#                        (8062, 'pyCIMS.Canada.Alberta.Petroleum Refining.'),
#                        (8063, 'pyCIMS.Canada.Alberta.Petroleum Refining.'),
#                        (8064, 'pyCIMS.Canada.Alberta.Petroleum Refining.'),
#                        (9621, 'pyCIMS.Canada.Alberta.Petroleum Refining.Steam'),
#                        (9806, 'pyCIMS.Canada.Alberta.Petroleum Refining.Steam'),
#                        (9820, 'pyCIMS.Canada.Alberta.Industrial Minerals.'),
#                        (9821, 'pyCIMS.Canada.Alberta.Industrial Minerals.'),
#                        (9822, 'pyCIMS.Canada.Alberta.Industrial Minerals.'),
#                        (9823, 'pyCIMS.Canada.Alberta.Industrial Minerals.'),
#                        (9824, 'pyCIMS.Canada.Alberta.Industrial Minerals.'),
#                        (11691,
#                         'pyCIMS.Canada.Alberta.Industrial Minerals.Steam'),
#                        (11876,
#                         'pyCIMS.Canada.Alberta.Industrial Minerals.Steam'),
#                        (11890, 'pyCIMS.Canada.Alberta.Chemical Products.'),
#                        (11891, 'pyCIMS.Canada.Alberta.Chemical Products.'),
#                        (11892, 'pyCIMS.Canada.Alberta.Chemical Products.'),
#                        (11893, 'pyCIMS.Canada.Alberta.Chemical Products.'),
#                        (11894, 'pyCIMS.Canada.Alberta.Chemical Products.'),
#                        (13761, 'pyCIMS.Canada.Alberta.Chemical Products.Steam'),
#                        (13946, 'pyCIMS.Canada.Alberta.Chemical Products.Steam'),
#                        (13960, 'pyCIMS.Canada.Alberta.Pulp and Paper.'),
#                        (13961, 'pyCIMS.Canada.Alberta.Pulp and Paper.'),
#                        (13962, 'pyCIMS.Canada.Alberta.Pulp and Paper.'),
#                        (13963, 'pyCIMS.Canada.Alberta.Pulp and Paper.'),
#                        (13964, 'pyCIMS.Canada.Alberta.Pulp and Paper.'),
#                        (15831, 'pyCIMS.Canada.Alberta.Pulp and Paper.Steam'),
#                        (16016, 'pyCIMS.Canada.Alberta.Pulp and Paper.Steam'),
#                        (16030, 'pyCIMS.Canada.Alberta.Other Manufacturing.'),
#                        (16031, 'pyCIMS.Canada.Alberta.Other Manufacturing.'),
#                        (16032, 'pyCIMS.Canada.Alberta.Other Manufacturing.'),
#                        (16033, 'pyCIMS.Canada.Alberta.Other Manufacturing.'),
#                        (16034, 'pyCIMS.Canada.Alberta.Other Manufacturing.'),
#                        (17901,
#                         'pyCIMS.Canada.Alberta.Other Manufacturing.Steam'),
#                        (18086,
#                         'pyCIMS.Canada.Alberta.Other Manufacturing.Steam'),
#                        (18100, 'pyCIMS.Canada.Alberta.Waste.'),
#                        (18101, 'pyCIMS.Canada.Alberta.Waste.'),
#                        (18102, 'pyCIMS.Canada.Alberta.Waste.'),
#                        (18103, 'pyCIMS.Canada.Alberta.Waste.'),
#                        (18104, 'pyCIMS.Canada.Alberta.Waste.'),
#                        (18118, 'pyCIMS.Canada.Alberta.Agriculture.'),
#                        (18119, 'pyCIMS.Canada.Alberta.Agriculture.'),
#                        (18120, 'pyCIMS.Canada.Alberta.Agriculture.'),
#                        (18121, 'pyCIMS.Canada.Alberta.Agriculture.'),
#                        (18122, 'pyCIMS.Canada.Alberta.Agriculture.')]}
