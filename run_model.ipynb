# %%
# Run this from the the /pycims_prototype/ directory
import os
import sys

sys.path.insert(0, os.path.abspath('pyCIMS'))
os.chdir(os.path.join(os.getcwd(), 'pyCIMS'))

import pyCIMS
from pprint import pprint

file = '../pyCIMS_model_description.xlsm'


# Create a model description reader
my_reader = pyCIMS.Reader(infile=file,
                          sheet_map={'model': 'Model',
                                     'incompatible': 'Incompatible',
                                     'default_tech': 'Technologies'},
                          node_col='Node')

# # If you want to validate that the model is defined correctly
# model_warnings = my_reader.validate_model(verbose=False)
# pprint(model_warnings)

# Create a model from the reader
my_model = pyCIMS.Model(my_reader)

# Run the Model
run_mod = my_model.run()
# Out:
# year: 2000
# done region
# done sector
# complete stacked (fixed ratio)
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.011284695884940573}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9887153041150595}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 7.66264949520997e-18}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 8.896825140288834e-24}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.013486996008765982}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9865130039912341}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9985212365910188}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 3.321238550830879e-05}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.001445551023472929}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.042390705196059586}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9576092948039404}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.04315217175044408}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9535657019848581}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0032821262646977726}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.1687769213222886}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.003378145138810739}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.2546986593407361}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.00363937237457529}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.23848938326725358}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0032488655614708903}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.3242699241380261}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.003498728856838741}
# complete compete
# year: 2005
# done region
# done sector
# complete stacked (fixed ratio)
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9999988406368598}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.1593631401447308e-06}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.914333995696167}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.08566600430383292}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0380271645784316}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9619728354215684}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9967513815516477}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.003248618448352279}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.4353348800736795}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.006415727376567132}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.5520816009088596}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.006167791640893921}
# complete compete
# year: 2010
# done region
# done sector
# complete stacked (fixed ratio)
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9999988280427896}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.1719572103947925e-06}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9228501540508169}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.07714984594918312}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.06667677200171451}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 5.560771180323082e-07}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9333226719211675}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9951883244189897}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.004811675581010211}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.45023414608196377}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.013684665664524804}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.5229253663895147}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.01315582186399671}
# complete compete
# year: 2015
# done region
# done sector
# complete stacked (fixed ratio)
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9999988374209573}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.1578921746618088e-06}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 4.686867955482233e-09}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.921390323555822}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.07860967644417804}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.10188927246465337}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 5.010664713598095e-07}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.8981102264688753}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.4330621596178867}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.005834867522959265}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.555493593747243}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.005609379111911054}
# complete compete
# year: 2020
# done region
# done sector
# complete stacked (fixed ratio)
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9999987805860732}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.2144722089189625e-06}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 4.9417179922014636e-09}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9405886946504063}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0594113053495937}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.19419009383495375}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 5.790055720233209e-07}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.8058093271594743}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.4175364700228956}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.09701282283637197}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.3921869441050499}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0932637630356825}
# complete compete
# year: 2025
# done region
# done sector
# complete stacked (fixed ratio)
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9999987972545433}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.1978786318869662e-06}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 4.8668247025434234e-09}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9355483130846234}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.06445168691537663}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.26970773696854455}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 4.878849999263766e-07}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.7302917751464555}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.4492703441279346}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.04946083370640257}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.4537194020016743}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.04754942016398848}
# complete compete
# year: 2030
# done region
# done sector
# complete stacked (fixed ratio)
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9999988092396043}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.1859473441926773e-06}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 4.813051557353152e-09}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9275320739521613}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.07246792604783867}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.36611701436075705}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 4.020739174418845e-07}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.6338825835653255}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.45580213857212204}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.02853554685290859}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.4882295237131671}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.02743279086180242}
# complete compete
# year: 2035
# done region
# done sector
# complete stacked (fixed ratio)
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9999988192225541}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.1760091350560112e-06}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 4.768310868221171e-09}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9126283952373324}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0873716047626675}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.47632327454149287}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 3.1780289727793647e-07}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.5236764076556099}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.45314002788812524}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.01711668941552353}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.5132880676131111}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.01645521508324003}
# complete compete
# year: 2040
# done region
# done sector
# complete stacked (fixed ratio)
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9999988231023312}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.1721467337361902e-06}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 4.750935069046669e-09}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.8865690667005294}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.11343093329947058}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.5951484550936387}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 2.414208772616658e-07}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.40485130348548404}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.45039186900956896}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.013831541455079208}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.5224795678946095}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.013297021640742191}
# complete compete
# year: 2045
# done region
# done sector
# complete stacked (fixed ratio)
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9999988231023312}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.1721467337361902e-06}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 4.750935069046669e-09}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.8413594547940073}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.15864054520599263}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.707259826110441}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.7456667877232912e-07}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.2927399993228803}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.45039186900956896}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.013831541455079208}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.5224795678946095}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.013297021640742191}
# complete compete
# year: 2050
# done region
# done sector
# complete stacked (fixed ratio)
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.9999988231023312}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.1721467337361902e-06}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 4.750935069046669e-09}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.7684639030445074}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.23153609695549268}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.7986880839083208}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.200462243445829e-07}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.2013117960454548}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 1.0}
# complete compete
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.45039186900956896}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.013831541455079208}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.0}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.5224795678946095}
# ms: {'source': None, 'branch': None, 'unit': '%', 'year_value': 0.013297021640742191}
# complete compete
# {'2000': {'Alberta': {'$': 217724000.0, 'person': 3004198.0},
#           'Buildings': {'Apartment': {'Clothes washing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Clothes '
#                                                                       'washing',
#                                                           'result': 161764.50769230767,
#                                                           'result_unit': 'unit',
#                                                           'value': 1.0},
#                                       'Dishwashing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Dishwashing',
#                                                       'result': 161764.50769230767,
#                                                       'result_unit': 'unit',
#                                                       'value': 1.0},
#                                       'Shell': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell',
#                                                 'result': 13711144.761281194,
#                                                 'result_unit': 'm2 floorspace',
#                                                 'value': 84.75990782453447},
#                                       'marketshare': 0.14},
#                         'Mobile': {'Clothes washing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Clothes '
#                                                                    'washing',
#                                                        'result': 46901.02846233999,
#                                                        'result_unit': 'unit',
#                                                        'value': 1.0},
#                                    'Dishwashing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Dishwashing',
#                                                    'result': 46901.02846233999,
#                                                    'result_unit': 'unit',
#                                                    'value': 1.0},
#                                    'Shell': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell',
#                                              'result': 4301828.65080629,
#                                              'result_unit': 'm2 floorspace',
#                                              'value': 91.72141404661348},
#                                    'marketshare': 0.040590758000000005},
#                         'Single Family Attached': {'Clothes washing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Clothes '
#                                                                                    'washing',
#                                                                        'result': 115546.07692307691,
#                                                                        'result_unit': 'unit',
#                                                                        'value': 1.0},
#                                                    'Dishwashing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Dishwashing',
#                                                                    'result': 115546.07692307691,
#                                                                    'result_unit': 'unit',
#                                                                    'value': 1.0},
#                                                    'Shell': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell',
#                                                              'result': 12405714.807702549,
#                                                              'result_unit': 'm2 '
#                                                                             'floorspace',
#                                                              'value': 107.36595424145357},
#                                                    'marketshare': 0.1},
#                         'Single Family Detached': {'Clothes washing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Clothes '
#                                                                                    'washing',
#                                                                        'result': 831249.1561530444,
#                                                                        'result_unit': 'unit',
#                                                                        'value': 1.0},
#                                                    'Dishwashing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Dishwashing',
#                                                                    'result': 831249.1561530444,
#                                                                    'result_unit': 'unit',
#                                                                    'value': 1.0},
#                                                    'Shell': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell',
#                                                              'result': 115141825.46215428,
#                                                              'result_unit': 'm2 '
#                                                                             'floorspace',
#                                                              'value': 138.51662237471803},
#                                                    'marketshare': 0.719409242},
#                         'building': 1155460.769230769},
#           'Clothes washing': {'Clothes washer_Existing': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                         'heating',
#                                                                             'result': 990082.7595511685,
#                                                                             'result_unit': 'GJ '
#                                                                                            'requested ',
#                                                                             'value': 19.857},
#                                                           'marketshare': 0.04315217175044408},
#                               'Clothes washer_Standard': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                         'heating',
#                                                                             'result': 12944037.558929095,
#                                                                             'result_unit': 'GJ '
#                                                                                            'requested ',
#                                                                             'value': 11.748},
#                                                           'marketshare': 0.9535657019848581},
#                               'Clothes washer_Steam': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                      'heating',
#                                                                          'result': 7774.354683966405,
#                                                                          'result_unit': 'GJ '
#                                                                                         'requested ',
#                                                                          'value': 2.05},
#                                                        'marketshare': 0.0032821262646977726},
#                               'unit': 1155460.7692307688},
#           'Dishwashing': {'Dishwasher_Standard': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                 'heating',
#                                                                     'result': 5134067.071920664,
#                                                                     'result_unit': 'GJ '
#                                                                                    'requested ',
#                                                                     'value': 4.64},
#                                                   'marketshare': 0.9576092948039404},
#                           'Dishwasher_existing': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                 'heating',
#                                                                     'result': 523702.67974991666,
#                                                                     'result_unit': 'GJ '
#                                                                                    'requested ',
#                                                                     'value': 10.692},
#                                                   'marketshare': 0.042390705196059586},
#                           'unit': 1155460.7692307688},
#           'Furnace': {'GJ': 91486960.61612864,
#                       'Heat pump_air source': {'marketshare': 3.321238550830879e-05},
#                       'Heat pump_ground source': {'marketshare': 0.0},
#                       'Natural Gas_existing': {'marketshare': 0.9985212365910188},
#                       'Natural Gas_high efficiency': {'marketshare': 0.001445551023472929}},
#           'Residential': {'household': 1155460.769230769},
#           'Shell': {'LEED': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                            'heating',
#                                                'result': 0.0,
#                                                'result_unit': 'GJ',
#                                                'value': 0.309},
#                              'marketshare': 0.0},
#                     'Post-1960': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                 'heating',
#                                                     'result': 91100035.4805349,
#                                                     'result_unit': 'GJ',
#                                                     'value': 0.633},
#                                   'marketshare': 0.9887153041150595},
#                     'Pre-1960': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                'heating',
#                                                    'result': 1637678.3113672035,
#                                                    'result_unit': 'GJ',
#                                                    'value': 0.997},
#                                  'marketshare': 0.011284695884940573},
#                     'R2000': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                             'heating',
#                                                 'result': 4.662095175211964e-16,
#                                                 'result_unit': 'GJ',
#                                                 'value': 0.36},
#                               'marketshare': 8.896825140288834e-24},
#                     'Standard': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                'heating',
#                                                    'result': 5.744202862940391e-10,
#                                                    'result_unit': 'GJ',
#                                                    'value': 0.515},
#                                  'marketshare': 7.66264949520997e-18},
#                     'm2 floorspace': 145560513.6819443},
#           'Space heating': {'Electric baseboard': {'marketshare': 0.013486996008765982},
#                             'Furnace': {'Furnace': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                 'heating.Furnace',
#                                                     'result': 91486960.61612864,
#                                                     'result_unit': 'GJ '
#                                                                    'requested ',
#                                                     'value': 1.0},
#                                         'marketshare': 0.9865130039912341},
#                             'GJ': 92737713.7919021},
#           'Water heating': {'Apartment_Electric_Standard': {'marketshare': 0.003498728856838741},
#                             'Apartment_Electric_existing stock': {'marketshare': 0.0032488655614708903},
#                             'Apartment_Natural Gas_Standard': {'marketshare': 0.3242699241380261},
#                             'Apartment_Natural Gas_existing stock': {'marketshare': 0.23848938326725358},
#                             'GJ': 13941894.673164232,
#                             'House_Electric_Standard': {'marketshare': 0.00363937237457529},
#                             'House_Electric_existing stock': {'marketshare': 0.003378145138810739},
#                             'House_Natural Gas_Standard': {'marketshare': 0.2546986593407361},
#                             'House_Natural Gas_existing stock': {'marketshare': 0.1687769213222886}}},
#  '2005': {'Alberta': {'$': 263911000.0, 'person': 3321768.0},
#           'Buildings': {'Apartment': {'Clothes washing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Clothes '
#                                                                       'washing',
#                                                           'result': 178225.62923076923,
#                                                           'result_unit': 'unit',
#                                                           'value': 1.0},
#                                       'Dishwashing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Dishwashing',
#                                                       'result': 178225.62923076923,
#                                                       'result_unit': 'unit',
#                                                       'value': 1.0},
#                                       'Shell': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell',
#                                                 'result': 15806326.441391014,
#                                                 'result_unit': 'm2 floorspace',
#                                                 'value': 88.68716867272072},
#                                       'marketshare': 0.1395},
#                         'Mobile': {'Clothes washing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Clothes '
#                                                                    'washing',
#                                                        'result': 51104.12307692312,
#                                                        'result_unit': 'unit',
#                                                        'value': 1.0},
#                                    'Dishwashing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Dishwashing',
#                                                    'result': 51104.12307692312,
#                                                    'result_unit': 'unit',
#                                                    'value': 1.0},
#                                    'Shell': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell',
#                                              'result': 4714987.320634091,
#                                              'result_unit': 'm2 floorspace',
#                                              'value': 92.26236625833464},
#                                    'marketshare': 0.040000000000000036},
#                         'Single Family Attached': {'Clothes washing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Clothes '
#                                                                                    'washing',
#                                                                        'result': 129037.91076923076,
#                                                                        'result_unit': 'unit',
#                                                                        'value': 1.0},
#                                                    'Dishwashing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Dishwashing',
#                                                                    'result': 129037.91076923076,
#                                                                    'result_unit': 'unit',
#                                                                    'value': 1.0},
#                                                    'Shell': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell',
#                                                              'result': 14353028.951653097,
#                                                              'result_unit': 'm2 '
#                                                                             'floorspace',
#                                                              'value': 111.23110151187905},
#                                                    'marketshare': 0.101},
#                         'Single Family Detached': {'Clothes washing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Clothes '
#                                                                                    'washing',
#                                                                        'result': 919235.4138461538,
#                                                                        'result_unit': 'unit',
#                                                                        'value': 1.0},
#                                                    'Dishwashing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Dishwashing',
#                                                                    'result': 919235.4138461538,
#                                                                    'result_unit': 'unit',
#                                                                    'value': 1.0},
#                                                    'Shell': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell',
#                                                              'result': 129630997.25474083,
#                                                              'result_unit': 'm2 '
#                                                                             'floorspace',
#                                                              'value': 141.0204560248114},
#                                                    'marketshare': 0.7195},
#                         'building': 1277603.0769230768},
#           'Clothes washing': {'Clothes washer_Existing': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                         'heating',
#                                                                             'result': 0.0,
#                                                                             'result_unit': 'GJ '
#                                                                                            'requested ',
#                                                                             'value': 19.857},
#                                                           'marketshare': 0.0},
#                               'Clothes washer_Standard': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                         'heating',
#                                                                             'result': 14960521.520709133,
#                                                                             'result_unit': 'GJ '
#                                                                                            'requested ',
#                                                                             'value': 11.748},
#                                                           'marketshare': 0.9967513815516477},
#                               'Clothes washer_Steam': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                      'heating',
#                                                                          'result': 8508.412096996084,
#                                                                          'result_unit': 'GJ '
#                                                                                         'requested ',
#                                                                          'value': 2.05},
#                                                        'marketshare': 0.003248618448352279},
#                               'unit': 1277603.076923077},
#           'Dishwashing': {'Dishwasher_Standard': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                 'heating',
#                                                                     'result': 5928078.276923077,
#                                                                     'result_unit': 'GJ '
#                                                                                    'requested ',
#                                                                     'value': 4.64},
#                                                   'marketshare': 1.0},
#                           'Dishwasher_existing': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                 'heating',
#                                                                     'result': 0.0,
#                                                                     'result_unit': 'GJ '
#                                                                                    'requested ',
#                                                                     'value': 10.692},
#                                                   'marketshare': 0.0},
#                           'unit': 1277603.076923077},
#           'Furnace': {'GJ': 7257642.775852005,
#                       'Heat pump_air source': {'marketshare': 0.0380271645784316},
#                       'Heat pump_ground source': {'marketshare': 0.0},
#                       'Natural Gas_existing': {'marketshare': 0.0},
#                       'Natural Gas_high efficiency': {'marketshare': 0.9619728354215684}},
#           'Residential': {'household': 1277603.0769230768},
#           'Shell': {'LEED': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                            'heating',
#                                                'result': 0.0,
#                                                'result_unit': 'GJ',
#                                                'value': 0.309},
#                              'marketshare': 0.0},
#                     'Post-1960': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                 'heating',
#                                                     'result': 0.0,
#                                                     'result_unit': 'GJ',
#                                                     'value': 0.633},
#                                   'marketshare': 0.0},
#                     'Pre-1960': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                'heating',
#                                                    'result': 0.0,
#                                                    'result_unit': 'GJ',
#                                                    'value': 0.997},
#                                  'marketshare': 0.0},
#                     'R2000': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                             'heating',
#                                                 'result': 68.6597139058906,
#                                                 'result_unit': 'GJ',
#                                                 'value': 0.36},
#                               'marketshare': 1.1593631401447308e-06},
#                     'Standard': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                'heating',
#                                                    'result': 84720151.86220063,
#                                                    'result_unit': 'GJ',
#                                                    'value': 0.515},
#                                  'marketshare': 0.9999988406368598},
#                     'm2 floorspace': 164505339.96841905},
#           'Space heating': {'Electric baseboard': {'marketshare': 0.914333995696167},
# ...
#                                  'marketshare': 0.0},
#                     'R2000': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                             'heating',
#                                                 'result': 143.8524144221151,
#                                                 'result_unit': 'GJ',
#                                                 'value': 0.36},
#                               'marketshare': 1.1721467337361902e-06},
#                     'Standard': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                'heating',
#                                                    'result': 175565586.2156851,
#                                                    'result_unit': 'GJ',
#                                                    'value': 0.515},
#                                  'marketshare': 0.9999988231023312},
#                     'm2 floorspace': 340904452.11389786},
#           'Space heating': {'Electric baseboard': {'marketshare': 0.8413594547940073},
#                             'Furnace': {'Furnace': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                 'heating.Furnace',
#                                                     'result': 27851843.21688485,
#                                                     'result_unit': 'GJ '
#                                                                    'requested ',
#                                                     'value': 1.0},
#                                         'marketshare': 0.15864054520599263},
#                             'GJ': 175565730.56856054},
#           'Water heating': {'Apartment_Electric_Standard': {'marketshare': 0.013297021640742191},
#                             'Apartment_Electric_existing stock': {'marketshare': 0.0},
#                             'Apartment_Natural Gas_Standard': {'marketshare': 0.5224795678946095},
#                             'Apartment_Natural Gas_existing stock': {'marketshare': 0.0},
#                             'GJ': 5161891.720138529,
#                             'House_Electric_Standard': {'marketshare': 0.013831541455079208},
#                             'House_Electric_existing stock': {'marketshare': 0.0},
#                             'House_Natural Gas_Standard': {'marketshare': 0.45039186900956896},
#                             'House_Natural Gas_existing stock': {'marketshare': 0.0}}},
#  '2050': {'Alberta': {'$': 646120876.0132201, 'person': 6769878.637478355},
#           'Buildings': {'Apartment': {'Clothes washing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Clothes '
#                                                                       'washing',
#                                                           'result': 351512.92925368383,
#                                                           'result_unit': 'unit',
#                                                           'value': 1.0},
#                                       'Dishwashing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Dishwashing',
#                                                       'result': 351512.92925368383,
#                                                       'result_unit': 'unit',
#                                                       'value': 1.0},
#                                       'Shell': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell',
#                                                 'result': 34424054.16887772,
#                                                 'result_unit': 'm2 floorspace',
#                                                 'value': 97.93111804440677},
#                                       'marketshare': 0.135},
#                         'Mobile': {'Clothes washing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Clothes '
#                                                                    'washing',
#                                                        'result': 104151.97903812602,
#                                                        'result_unit': 'unit',
#                                                        'value': 1.0},
#                                    'Dishwashing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Dishwashing',
#                                                    'result': 104151.97903812602,
#                                                    'result_unit': 'unit',
#                                                    'value': 1.0},
#                                    'Shell': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell',
#                                              'result': 9898393.29432207,
#                                              'result_unit': 'm2 floorspace',
#                                              'value': 95.03797609739753},
#                                    'marketshare': 0.039999999999999036},
#                         'Single Family Attached': {'Clothes washing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Clothes '
#                                                                                    'washing',
#                                                                        'result': 286417.9423548535,
#                                                                        'result_unit': 'unit',
#                                                                        'value': 1.0},
#                                                    'Dishwashing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Dishwashing',
#                                                                    'result': 286417.9423548535,
#                                                                    'result_unit': 'unit',
#                                                                    'value': 1.0},
#                                                    'Shell': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell',
#                                                              'result': 35117363.4401308,
#                                                              'result_unit': 'm2 '
#                                                                             'floorspace',
#                                                              'value': 122.60881127559612},
#                                                    'marketshare': 0.11},
#                         'Single Family Detached': {'Clothes washing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Clothes '
#                                                                                    'washing',
#                                                                        'result': 1861716.6253065502,
#                                                                        'result_unit': 'unit',
#                                                                        'value': 1.0},
#                                                    'Dishwashing': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Dishwashing',
#                                                                    'result': 1861716.6253065502,
#                                                                    'result_unit': 'unit',
#                                                                    'value': 1.0},
#                                                    'Shell': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell',
#                                                              'result': 273082125.58432096,
#                                                              'result_unit': 'm2 '
#                                                                             'floorspace',
#                                                              'value': 146.68297090560455},
#                                                    'marketshare': 0.715000000000001},
#                         'building': 2603799.4759532134},
#           'Clothes washing': {'Clothes washer_Existing': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                         'heating',
#                                                                             'result': 0.0,
#                                                                             'result_unit': 'GJ '
#                                                                                            'requested ',
#                                                                             'value': 19.857},
#                                                           'marketshare': 0.0},
#                               'Clothes washer_Standard': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                         'heating',
#                                                                             'result': 0.0,
#                                                                             'result_unit': 'GJ '
#                                                                                            'requested ',
#                                                                             'value': 11.748},
#                                                           'marketshare': 0.0},
#                               'Clothes washer_Steam': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                      'heating',
#                                                                          'result': 5337788.925704087,
#                                                                          'result_unit': 'GJ '
#                                                                                         'requested ',
#                                                                          'value': 2.05},
#                                                        'marketshare': 1.0},
#                               'unit': 2603799.4759532134},
#           'Dishwashing': {'Dishwasher_Standard': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                 'heating',
#                                                                     'result': 12081629.56842291,
#                                                                     'result_unit': 'GJ '
#                                                                                    'requested ',
#                                                                     'value': 4.64},
#                                                   'marketshare': 1.0},
#                           'Dishwasher_existing': {'Water heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Water '
#                                                                                 'heating',
#                                                                     'result': 0.0,
#                                                                     'result_unit': 'GJ '
#                                                                                    'requested ',
#                                                                     'value': 10.692},
#                                                   'marketshare': 0.0},
#                           'unit': 2603799.4759532134},
#           'Furnace': {'GJ': 42035085.022644445,
#                       'Heat pump_air source': {'marketshare': 0.7986880839083208},
#                       'Heat pump_ground source': {'marketshare': 1.200462243445829e-07},
#                       'Natural Gas_existing': {'marketshare': 0.0},
#                       'Natural Gas_high efficiency': {'marketshare': 0.2013117960454548}},
#           'Residential': {'household': 2603799.4759532134},
#           'Shell': {'LEED': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                            'heating',
#                                                'result': 0.5175159286762346,
#                                                'result_unit': 'GJ',
#                                                'value': 0.309},
#                              'marketshare': 4.750935069046669e-09},
#                     'Post-1960': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                 'heating',
#                                                     'result': 0.0,
#                                                     'result_unit': 'GJ',
#                                                     'value': 0.633},
#                                   'marketshare': 0.0},
#                     'Pre-1960': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                'heating',
#                                                    'result': 0.0,
#                                                    'result_unit': 'GJ',
#                                                    'value': 0.997},
#                                  'marketshare': 0.0},
#                     'R2000': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                             'heating',
#                                                 'result': 148.7546771127687,
#                                                 'result_unit': 'GJ',
#                                                 'value': 0.36},
#                               'marketshare': 1.1721467337361902e-06},
#                     'Standard': {'Space heating': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                'heating',
#                                                    'result': 181548583.62678424,
#                                                    'result_unit': 'GJ',
#                                                    'value': 0.515},
#                                  'marketshare': 0.9999988231023312},
#                     'm2 floorspace': 352521936.4876515},
#           'Space heating': {'Electric baseboard': {'marketshare': 0.7684639030445074},
#                             'Furnace': {'Furnace': {'location': 'pyCIMS.Canada.Alberta.Residential.Buildings.Shell.Space '
#                                                                 'heating.Furnace',
#                                                     'result': 42035085.022644445,
#                                                     'result_unit': 'GJ '
#                                                                    'requested ',
#                                                     'value': 1.0},
#                                         'marketshare': 0.23153609695549268},
#                             'GJ': 181548732.89897728},
#           'Water heating': {'Apartment_Electric_Standard': {'marketshare': 0.013297021640742191},
#                             'Apartment_Electric_existing stock': {'marketshare': 0.0},
#                             'Apartment_Natural Gas_Standard': {'marketshare': 0.5224795678946095},
#                             'Apartment_Natural Gas_existing stock': {'marketshare': 0.0},
#                             'GJ': 5337788.925704087,
#                             'House_Electric_Standard': {'marketshare': 0.013831541455079208},
#                             'House_Electric_existing stock': {'marketshare': 0.0},
#                             'House_Natural Gas_Standard': {'marketshare': 0.45039186900956896},
#                             'House_Natural Gas_existing stock': {'marketshare': 0.0}}}}
